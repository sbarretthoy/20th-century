# %% [markdown]
# # Text mining LOTR

# %%
from textblob import TextBlob 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import nltk
import re
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from collections import Counter
sns.set()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ## Tokenization

# %%
myfile = open('alice_in_wonderland.txt', encoding='utf-8')

# %%
# Import txt file

with open('alice_in_wonderland.txt', 'r', errors='ignore') as file:
    data = file.read().replace('\n', '')

# %%
# Sentence tokenization 

from nltk.tokenize import sent_tokenize
tokenized_sent = sent_tokenize(data)
print(tokenized_sent)
# Out:
# ["Alice's Adventures in Wonderland                ALICE'S ADVENTURES IN WONDERLAND                          Lewis Carroll               THE MILLENNIUM FULCRUM EDITION 3.0                            CHAPTER I                      Down the Rabbit-Hole  Alice was beginning to get very tired of sitting by her sisteron the bank, and of having nothing to do:  once or twice she hadpeeped into the book her sister was reading, but it had nopictures or conversations in it, `and what is the use of a book,'thought Alice `without pictures or conversation?'", 'So she was considering in her own mind (as well as she could,for the hot day made her feel very sleepy and stupid), whetherthe pleasure of making a daisy-chain would be worth the troubleof getting up and picking the daisies, when suddenly a WhiteRabbit with pink eyes ran close by her.', 'There was nothing so VERY remarkable in that; nor did Alicethink it so VERY much out of the way to hear the Rabbit say toitself, `Oh dear!', 'Oh dear!', "I shall be late!'", '(when she thoughtit over afterwards, it occurred to her that she ought to havewondered at this, but at the time it all seemed quite natural);but when the Rabbit actually TOOK A WATCH OUT OF ITS WAISTCOAT-POCKET, and looked at it, and then hurried on, Alice started toher feet, for it flashed across her mind that she had neverbefore seen a rabbit with either a waistcoat-pocket, or a watch totake out of it, and burning with curiosity, she ran across thefield after it, and fortunately was just in time to see it popdown a large rabbit-hole under the hedge.', 'In another moment down went Alice after it, never onceconsidering how in the world she was to get out again.', 'The rabbit-hole went straight on like a tunnel for some way,and then dipped suddenly down, so suddenly that Alice had not amoment to think about stopping herself before she found herselffalling down a very deep well.', 'Either the well was very deep, or she fell very slowly, for shehad plenty of time as she went down to look about her and towonder what was going to happen next.', 'First, she tried to lookdown and make out what she was coming to, but it was too dark tosee anything; then she looked at the sides of the well, andnoticed that they were filled with cupboards and book-shelves;here and there she saw maps and pictures hung upon pegs.', "Shetook down a jar from one of the shelves as she passed; it waslabelled `ORANGE MARMALADE', but to her great disappointment itwas empty:  she did not like to drop the jar for fear of killingsomebody, so managed to put it into one of the cupboards as shefell past it.", "`Well!'", 'thought Alice to herself, `after such a fall as this, Ishall think nothing of tumbling down stairs!', "How brave they'llall think me at home!", "Why, I wouldn't say anything about it,even if I fell off the top of the house!'", '(Which was very likelytrue.)', 'Down, down, down.', 'Would the fall NEVER come to an end!', "`Iwonder how many miles I've fallen by this time?'", 'she said aloud.`I must be getting somewhere near the centre of the earth.', "Letme see:  that would be four thousand miles down, I think--' (for,you see, Alice had learnt several things of this sort in herlessons in the schoolroom, and though this was not a VERY goodopportunity for showing off her knowledge, as there was no one tolisten to her, still it was good practice to say it over) `--yes,that's about the right distance--but then I wonder what Latitudeor Longitude I've got to?'", '(Alice had no idea what Latitude was,or Longitude either, but thought they were nice grand words tosay.)', 'Presently she began again.', '`I wonder if I shall fall rightTHROUGH the earth!', "How funny it'll seem to come out among thepeople that walk with their heads downward!", "The Antipathies, Ithink--' (she was rather glad there WAS no one listening, thistime, as it didn't sound at all the right word) `--but I shallhave to ask them what the name of the country is, you know.Please, Ma'am, is this New Z ...

# %%
# Word tokenization

from nltk.tokenize import word_tokenize
tokenized_word = word_tokenize(data)
print(tokenized_word)
# Out:
# ['Alice', "'s", 'Adventures', 'in', 'Wonderland', 'ALICE', "'S", 'ADVENTURES', 'IN', 'WONDERLAND', 'Lewis', 'Carroll', 'THE', 'MILLENNIUM', 'FULCRUM', 'EDITION', '3.0', 'CHAPTER', 'I', 'Down', 'the', 'Rabbit-Hole', 'Alice', 'was', 'beginning', 'to', 'get', 'very', 'tired', 'of', 'sitting', 'by', 'her', 'sisteron', 'the', 'bank', ',', 'and', 'of', 'having', 'nothing', 'to', 'do', ':', 'once', 'or', 'twice', 'she', 'hadpeeped', 'into', 'the', 'book', 'her', 'sister', 'was', 'reading', ',', 'but', 'it', 'had', 'nopictures', 'or', 'conversations', 'in', 'it', ',', '`', 'and', 'what', 'is', 'the', 'use', 'of', 'a', 'book', ',', "'thought", 'Alice', '`', 'without', 'pictures', 'or', 'conversation', '?', "'", 'So', 'she', 'was', 'considering', 'in', 'her', 'own', 'mind', '(', 'as', 'well', 'as', 'she', 'could', ',', 'for', 'the', 'hot', 'day', 'made', 'her', 'feel', 'very', 'sleepy', 'and', 'stupid', ')', ',', 'whetherthe', 'pleasure', 'of', 'making', 'a', 'daisy-chain', 'would', 'be', 'worth', 'the', 'troubleof', 'getting', 'up', 'and', 'picking', 'the', 'daisies', ',', 'when', 'suddenly', 'a', 'WhiteRabbit', 'with', 'pink', 'eyes', 'ran', 'close', 'by', 'her', '.', 'There', 'was', 'nothing', 'so', 'VERY', 'remarkable', 'in', 'that', ';', 'nor', 'did', 'Alicethink', 'it', 'so', 'VERY', 'much', 'out', 'of', 'the', 'way', 'to', 'hear', 'the', 'Rabbit', 'say', 'toitself', ',', '`', 'Oh', 'dear', '!', 'Oh', 'dear', '!', 'I', 'shall', 'be', 'late', '!', "'", '(', 'when', 'she', 'thoughtit', 'over', 'afterwards', ',', 'it', 'occurred', 'to', 'her', 'that', 'she', 'ought', 'to', 'havewondered', 'at', 'this', ',', 'but', 'at', 'the', 'time', 'it', 'all', 'seemed', 'quite', 'natural', ')', ';', 'but', 'when', 'the', 'Rabbit', 'actually', 'TOOK', 'A', 'WATCH', 'OUT', 'OF', 'ITS', 'WAISTCOAT-POCKET', ',', 'and', 'looked', 'at', 'it', ',', 'and', 'then', 'hurried', 'on', ',', 'Alice', 'started', 'toher', 'feet', ',', 'for', 'it', 'flashed', 'across', 'her', 'mind', 'that', 'she', 'had', 'neverbefore', 'seen', 'a', 'rabbit', 'with', 'either', 'a', 'waistcoat-pocket', ',', 'or', 'a', 'watch', 'totake', 'out', 'of', 'it', ',', 'and', 'burning', 'with', 'curiosity', ',', 'she', 'ran', 'across', 'thefield', 'after', 'it', ',', 'and', 'fortunately', 'was', 'just', 'in', 'time', 'to', 'see', 'it', 'popdown', 'a', 'large', 'rabbit-hole', 'under', 'the', 'hedge', '.', 'In', 'another', 'moment', 'down', 'went', 'Alice', 'after', 'it', ',', 'never', 'onceconsidering', 'how', 'in', 'the', 'world', 'she', 'was', 'to', 'get', 'out', 'again', '.', 'The', 'rabbit-hole', 'went', 'straight', 'on', 'like', 'a', 'tunnel', 'for', 'some', 'way', ',', 'and', 'then', 'dipped', 'suddenly', 'down', ',', 'so', 'suddenly', 'that', 'Alice', 'had', 'not', 'amoment', 'to', 'think', 'about', 'stopping', 'herself', 'before', 'she', 'found', 'herselffalling', 'down', 'a', 'very', 'deep', 'well', '.', 'Either', 'the', 'well', 'was', 'very', 'deep', ',', 'or', 'she', 'fell', 'very', 'slowly', ',', 'for', 'shehad', 'plenty', 'of', 'time', 'as', 'she', 'went', 'down', 'to', 'look', 'about', 'her', 'and', 'towonder', 'what', 'was', 'going', 'to', 'happen', 'next', '.', 'First', ',', 'she', 'tried', 'to', 'lookdown', 'and', 'make', 'out', 'what', 'she', 'was', 'coming', 'to', ',', 'but', 'it', 'was', 'too', 'dark', 'tosee', 'anything', ';', 'then', 'she', 'looked', 'at', 'the', 'sides', 'of', 'the', 'well', ',', 'andnoticed', 'that', 'they', 'were', 'filled', 'with', 'cupboards', 'and', 'book-shelves', ';', 'here', 'and', 'there', 'she', 'saw', 'maps', 'and', 'pictures', 'hung', 'upon', 'pegs', '.', 'Shetook', 'down', 'a', 'jar', 'from', 'one', 'of', 'the', 'shelves', 'as', 'she', 'passed', ';', 'it', 'waslabelled', '`', 'ORANGE', 'MARMALADE', "'", ',', 'but', 'to', 'her', 'great', 'disappointment', 'itwas', 'empty', ':', 'she', 'did', 'not', 'like', 'to', 'drop', 'the', 'jar', 'for', 'fear', 'of', 'killingsomebody', ',', 'so', 'managed', 'to', 'put', 'it', 'into', 'one', 'of', 'the' ...

# %%
# Create frequency distribution

from nltk.probability import FreqDist
dist_words = FreqDist(tokenized_word)
print(dist_words)
# Out:
# <FreqDist with 4133 samples and 32850 outcomes>

# %%
dist_words.most_common(10)
# Out:
# [(',', 2418),
#  ('the', 1342),
#  ('`', 1109),
#  ("'", 1076),
#  ('.', 920),
#  ('and', 714),
#  ('to', 647),
#  ('a', 547),
#  ('I', 487),
#  ('it', 471)]

# %%
# Frequency Distribution Plot

plt.figure(figsize=(8, 3))
dist_words.plot(10,cumulative = False)
plt.show()

# %% [markdown]
# ## Stopwords

# %%
# Defining stopwords

from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))
print(stop_words)
# Out:
# {'should', 'any', 'its', 'who', 'does', 'are', "won't", 'is', "you're", 'into', 'some', 'of', 'each', 'won', 'the', 've', 'to', 'than', 'her', 'him', 'be', 'itself', 'over', 'same', 'themselves', 'a', 'he', 'been', 'your', 'having', 'up', 'herself', 'wouldn', 'and', 're', 'those', 'what', "you'd", 'shan', 'out', 'yourselves', 'don', 'between', 'needn', "you'll", 'no', 'before', "wouldn't", 'now', 'from', 'hers', 'few', 'why', 'this', "wasn't", 'in', 'such', 'for', 'only', 'she', 'd', 'you', 'doing', 'had', "hasn't", 'with', 'himself', 'down', "that'll", 'yourself', "you've", 'off', 'because', 'until', 's', 'mustn', "mustn't", 'weren', 'being', 'their', 'very', "didn't", "aren't", 'other', "she's", 'all', 'under', 'ourselves', 'too', 'yours', 'shouldn', 'above', 'll', 'by', 'hadn', "haven't", 'own', 'myself', 'they', 'through', 'an', 'these', "couldn't", 'as', 'after', 'isn', "shouldn't", 'then', 'aren', 'i', 'has', 'do', 'but', 'couldn', 'haven', 'further', 'did', 'there', 'during', 'y', "mightn't", 'against', 'm', 'were', 'or', 't', 'hasn', 'ma', 'can', "needn't", 'me', 'below', 'ours', 'about', 'theirs', 'will', 'my', 'his', 'that', 'doesn', 'here', 'if', 'how', 'was', "it's", 'we', 'have', 'more', 'just', 'where', 'not', 'mightn', "hadn't", 'didn', 'our', 'whom', 'on', 'which', 'when', 'so', 'while', 'nor', 'most', "don't", 'ain', 'them', 'once', 'both', 'o', 'at', 'again', 'it', 'wasn', "weren't", "should've", 'am', "isn't", "doesn't", "shan't"}

# %%
# Removing stopwords in sentences

# filtered_sent = []
# for word in tokenized_sent:
#     if word not in stop_words:
#         filtered_sent.append(word)
# print("Tokenized Sentence:", tokenized_sent)
# print("Filterd Sentence:", filtered_sent)

# %%
# Removing stopwords in words

filtered_words = [] # creates an empty list
for word in tokenized_word:
    if word not in stop_words:
        filtered_words.append(word)

# %%
filtered_words
# Out:
# ['Alice',
#  "'s",
#  'Adventures',
#  'Wonderland',
#  'ALICE',
#  "'S",
#  'ADVENTURES',
#  'IN',
#  'WONDERLAND',
#  'Lewis',
#  'Carroll',
#  'THE',
#  'MILLENNIUM',
#  'FULCRUM',
#  'EDITION',
#  '3.0',
#  'CHAPTER',
#  'I',
#  'Down',
#  'Rabbit-Hole',
#  'Alice',
#  'beginning',
#  'get',
#  'tired',
#  'sitting',
#  'sisteron',
#  'bank',
#  ',',
#  'nothing',
#  ':',
#  'twice',
#  'hadpeeped',
#  'book',
#  'sister',
#  'reading',
#  ',',
#  'nopictures',
#  'conversations',
#  ',',
#  '`',
#  'use',
#  'book',
#  ',',
#  "'thought",
#  'Alice',
#  '`',
#  'without',
#  'pictures',
#  'conversation',
#  '?',
#  "'",
#  'So',
#  'considering',
#  'mind',
#  '(',
#  'well',
#  'could',
#  ',',
#  'hot',
#  'day',
#  'made',
#  'feel',
#  'sleepy',
#  'stupid',
#  ')',
#  ',',
#  'whetherthe',
#  'pleasure',
#  'making',
#  'daisy-chain',
#  'would',
#  'worth',
#  'troubleof',
#  'getting',
#  'picking',
#  'daisies',
#  ',',
#  'suddenly',
#  'WhiteRabbit',
#  'pink',
#  'eyes',
#  'ran',
#  'close',
#  '.',
#  'There',
#  'nothing',
#  'VERY',
#  'remarkable',
#  ';',
#  'Alicethink',
#  'VERY',
#  'much',
#  'way',
#  'hear',
#  'Rabbit',
#  'say',
#  'toitself',
#  ',',
#  '`',
#  'Oh',
#  'dear',
#  '!',
#  'Oh',
#  'dear',
#  '!',
#  'I',
#  'shall',
#  'late',
#  '!',
#  "'",
#  '(',
#  'thoughtit',
#  'afterwards',
#  ',',
#  'occurred',
#  'ought',
#  'havewondered',
#  ',',
#  'time',
#  'seemed',
#  'quite',
#  'natural',
#  ')',
#  ';',
#  'Rabbit',
#  'actually',
#  'TOOK',
#  'A',
#  'WATCH',
#  'OUT',
#  'OF',
#  'ITS',
#  'WAISTCOAT-POCKET',
#  ',',
#  'looked',
#  ',',
#  'hurried',
#  ',',
#  'Alice',
#  'started',
#  'toher',
#  'feet',
#  ',',
#  'flashed',
#  'across',
#  'mind',
#  'neverbefore',
#  'seen',
#  'rabbit',
#  'either',
#  'waistcoat-pocket',
#  ',',
#  'watch',
#  'totake',
#  ',',
#  'burning',
#  'curiosity',
#  ',',
#  'ran',
#  'across',
#  'thefield',
#  ',',
#  'fortunately',
#  'time',
#  'see',
#  'popdown',
#  'large',
#  'rabbit-hole',
#  'hedge',
#  '.',
#  'In',
#  'another',
#  'moment',
#  'went',
#  'Alice',
#  ',',
#  'never',
#  'onceconsidering',
#  'world',
#  'get',
#  '.',
#  'The',
#  'rabbit-hole',
#  'went',
#  'straight',
#  'like',
#  'tunnel',
#  'way',
#  ',',
#  'dipped',
#  'suddenly',
#  ',',
#  'suddenly',
#  'Alice',
#  'amoment',
#  'think',
#  'stopping',
#  'found',
#  'herselffalling',
#  'deep',
#  'well',
#  '.',
#  'Either',
#  'well',
#  'deep',
#  ',',
#  'fell',
#  'slowly',
#  ',',
#  'shehad',
#  'plenty',
#  'time',
#  'went',
#  'look',
#  'towonder',
#  'going',
#  'happen',
#  'next',
#  '.',
#  'First',
#  ',',
#  'tried',
#  'lookdown',
#  'make',
#  'coming',
#  ',',
#  'dark',
#  'tosee',
#  'anything',
#  ';',
#  'looked',
#  'sides',
#  'well',
#  ',',
#  'andnoticed',
#  'filled',
#  'cupboards',
#  'book-shelves',
#  ';',
#  'saw',
#  'maps',
#  'pictures',
#  'hung',
#  'upon',
#  'pegs',
#  '.',
#  'Shetook',
#  'jar',
#  'one',
#  'shelves',
#  'passed',
#  ';',
#  'waslabelled',
#  '`',
#  'ORANGE',
#  'MARMALADE',
#  "'",
#  ',',
#  'great',
#  'disappointment',
#  'itwas',
#  'empty',
#  ':',
#  'like',
#  'drop',
#  'jar',
#  'fear',
#  'killingsomebody',
#  ',',
#  'managed',
#  'put',
#  'one',
#  'cupboards',
#  'shefell',
#  'past',
#  '.',
#  '`',
#  'Well',
#  '!',
#  "'",
#  'thought',
#  'Alice',
#  ',',
#  '`',
#  'fall',
#  ',',
#  'Ishall',
#  'think',
#  'nothing',
#  'tumbling',
#  'stairs',
#  '!',
#  'How',
#  'brave',
#  "they'llall",
#  'think',
#  'home',
#  '!',
#  'Why',
#  ',',
#  'I',
#  'would',
#  "n't",
#  'say',
#  'anything',
#  ',',
#  'even',
#  'I',
#  'fell',
#  'top',
#  'house',
#  '!',
#  "'",
#  '(',
#  'Which',
#  'likelytrue',
#  '.',
#  ')',
#  'Down',
#  ',',
#  ',',
#  '.',
#  'Would',
#  'fall',
#  'NEVER',
#  'come',
#  'end',
#  '!',
#  '`',
#  'Iwonder',
#  'many',
#  'miles',
#  'I',
#  "'ve",
#  'fallen',
#  'time',
#  '?',
#  "'",
#  'said',
#  'aloud.',
#  '`',
#  'I',
#  'must',
#  'getting',
#  'somewhere',
#  'near',
#  'centre',
#  'earth',
#  '.',
#  'Letme',
#  'see',
#  ':',
#  'would',
#  'four',
#  'thousand',
#  'miles',
#  ',',
#  'I',
#  'think',
#  '--',
#  "'",
#  '(',
#  ',',
#  'see',
#  ',',
#  'Alice',
#  'learnt',
#  'several',
#  'things',
#  'sort',
#  'herlessons',
#  'schoolroom',
#  ',',
#  'though',
#  'VERY',
#  'goodopportunity',
#  'showing',
#  'knowledge',
#  ',',
#  'one',
#  'tolisten',
#  ',',
#  'still',
#  'good',
#  'practice',
#  'say',
#  ')',
#  '`',
#  '--',
#  'yes',
#  ',',
#  "'s",
#  'right',
#  'distance',
#  '--',
#  'I',
#  'wonder',
#  'Latitudeor',
#  'Longitude',
#  'I',
#  "'ve",
#  'got',
#  '?',
#  "'",
#  '(',
#  'Alice',
#  'idea',
#  'Latitude',
#  ',',
#  'Longitude',
#  'either',
#  ',',
#  'thought',
#  'nice',
#  'grand',
#  'words',
#  'tosay',
#  '.',
#  ')',
#  'Presently',
#  'began',
#  '.',
#  '`',
#  'I',
#  'wonder',
#  'I',
#  'shall',
#  'fall',
#  'rightTHROUGH',
#  'earth',
#  '!',
#  'How',
#  'funny',
#  "'ll",
#  'seem',
#  'come',
#  'among',
#  'thepeople',
#  'walk',
#  'heads',
#  'downward',
#  '!',
#  'The',
#  'Antipathies',
#  ',',
#  'Ithink',
#  '--',
#  "'",
#  '(',
#  'rather',
#  'glad',
#  'WAS',
#  'one',
#  'listening',
#  ',',
#  'thistime',
#  ',',
#  "n't",
#  'sound',
#  'right',
#  'word',
#  ')',
#  '`',
#  '--',
#  'I',
#  'shallhave',
#  'ask',
#  'name',
#  'country',
#  ',',
#  'know.Please',
#  ',',
#  "Ma'am",
#  ',',
#  'New',
#  'Zealand',
#  'Australia',
#  '?',
#  "'",
#  '(',
#  'triedto',
#  'curtsey',
#  'spoke',
#  '--',
#  'fancy',
#  'CURTSEYING',
#  "'re",
#  'fallingthrough',
#  'air',
#  '!',
#  'Do',
#  'think',
#  'could',
#  'manage',
#  '?',
#  ')',
#  '`',
#  'And',
#  'whatan',
#  'ignorant',
#  'little',
#  'girl',
#  "'ll",
#  'think',
#  'asking',
#  '!',
#  'No',
#  ',',
#  "it'llnever",
#  'ask',
#  ':',
#  'perhaps',
#  'I',
#  'shall',
#  'see',
#  'written',
#  'somewhere',
#  '.',
#  "'",
#  'Down',
#  ',',
#  ',',
#  '.',
#  'There',
#  'nothing',
#  'else',
#  ',',
#  'Alice',
#  'soonbegan',
#  'talking',
#  '.',
#  '`',
#  'Dinah',
#  "'ll",
#  'miss',
#  'much',
#  'to-night',
#  ',',
#  'Ishould',
#  'think',
#  '!',
#  "'",
#  '(',
#  'Dinah',
#  'cat',
#  '.',
#  ')',
#  '`',
#  'I',
#  'hope',
#  "'ll",
#  'rememberher',
#  'saucer',
#  'milk',
#  'tea-time',
#  '.',
#  'Dinah',
#  'dear',
#  '!',
#  'I',
#  'wish',
#  'weredown',
#  '!',
#  'There',
#  'mice',
#  'air',
#  ',',
#  'I',
#  "'m",
#  'afraid',
#  ',',
#  'butyou',
#  'might',
#  'catch',
#  'bat',
#  ',',
#  "'s",
#  'like',
#  'mouse',
#  ',',
#  'know.But',
#  'cats',
#  'eat',
#  'bats',
#  ',',
#  'I',
#  'wonder',
#  '?',
#  "'",
#  'And',
#  'Alice',
#  'began',
#  'getrather',
#  'sleepy',
#  ',',
#  'went',
#  'saying',
#  ',',
#  'dreamy',
#  'sort',
#  'ofway',
#  ',',
#  '`',
#  'Do',
#  'cats',
#  'eat',
#  'bats',
#  '?',
#  'Do',
#  'cats',
#  'eat',
#  'bats',
#  '?',
#  "'",
#  'sometimes',
#  ',',
#  '`',
#  'Dobats',
#  'eat',
#  'cats',
#  '?',
#  "'",
#  ',',
#  'see',
#  ',',
#  'could',
#  "n't",
#  'answer',
#  'eitherquestion',
#  ',',
#  "n't",
#  'much',
#  'matter',
#  'way',
#  'put',
#  '.',
#  'She',
#  'feltthat',
#  'dozing',
#  ',',
#  'begun',
#  'dream',
#  'shewas',
#  'walking',
#  'hand',
#  'hand',
#  'Dinah',
#  ',',
#  'saying',
#  'veryearnestly',
#  ',',
#  '`',
#  'Now',
#  ',',
#  'Dinah',
#  ',',
#  'tell',
#  'truth',
#  ':',
#  'ever',
#  'eat',
#  'abat',
#  '?',
#  "'",
#  'suddenly',
#  ',',
#  'thump',
#  '!',
#  'thump',
#  '!',
#  'came',
#  'upon',
#  'heap',
#  'ofsticks',
#  'dry',
#  'leaves',
#  ',',
#  'fall',
#  '.',
#  'Alice',
#  'bit',
#  'hurt',
#  ',',
#  'jumped',
#  'feet',
#  'amoment',
#  ':',
#  'looked',
#  ',',
#  'dark',
#  'overhead',
#  ';',
#  'herwas',
#  'another',
#  'long',
#  'passage',
#  ',',
#  'White',
#  'Rabbit',
#  'still',
#  'insight',
#  ',',
#  'hurrying',
#  '.',
#  'There',
#  'moment',
#  'lost',
#  ':',
#  'away',
#  'went',
#  'Alice',
#  'like',
#  'wind',
#  ',',
#  'time',
#  'hear',
#  'itsay',
#  ',',
#  'turned',
#  'corner',
#  ',',
#  '`',
#  'Oh',
#  'ears',
#  'whiskers',
#  ',',
#  'lateit',
#  "'s",
#  'getting',
#  '!',
#  "'",
#  'She',
#  'close',
#  'behind',
#  'turned',
#  'thecorner',
#  ',',
#  'Rabbit',
#  'longer',
#  'seen',
#  ':',
#  'foundherself',
#  'long',
#  ',',
#  'low',
#  'hall',
#  ',',
#  'lit',
#  'row',
#  'lampshanging',
#  'roof',
#  '.',
#  'There',
#  'doors',
#  'round',
#  'hall',
#  ',',
#  'locked',
#  ';',
#  'Alice',
#  'way',
#  'one',
#  'side',
#  'theother',
#  ',',
#  'trying',
#  'every',
#  'door',
#  ',',
#  'walked',
#  'sadly',
#  'middle',
#  ',',
#  'wondering',
#  'ever',
#  'get',
#  '.',
#  'Suddenly',
#  'came',
#  'upon',
#  'little',
#  'three-legged',
#  'table',
#  ',',
#  'made',
#  'ofsolid',
#  'glass',
#  ';',
#  'nothing',
#  'except',
#  'tiny',
#  'golden',
#  'key',
#  ',',
#  'Alice',
#  "'s",
#  'first',
#  'thought',
#  'might',
#  'belong',
#  'one',
#  'thedoors',
#  'hall',
#  ';',
#  ',',
#  'alas',
#  '!',
#  'either',
#  'locks',
#  'large',
#  ',',
#  'orthe',
#  'key',
#  'small',
#  ',',
#  'rate',
#  'would',
#  'open',
#  'ofthem',
#  '.',
#  'However',
#  ',',
#  'second',
#  'time',
#  'round',
#  ',',
#  'came',
#  'upon',
#  'lowcurtain',
#  'noticed',
#  ',',
#  'behind',
#  'littledoor',
#  'fifteen',
#  'inches',
#  'high',
#  ':',
#  'tried',
#  'little',
#  'golden',
#  'keyin',
#  'lock',
#  ',',
#  'great',
#  'delight',
#  'fitted',
#  '!',
#  'Alice',
#  'opened',
#  'door',
#  'found',
#  'led',
#  'smallpassage',
#  ',',
#  'much',
#  'larger',
#  'rat-hole',
#  ':',
#  'knelt',
#  'andlooked',
#  'along',
#  'passage',
#  'loveliest',
#  'garden',
#  'ever',
#  'saw.How',
#  'longed',
#  'get',
#  'dark',
#  'hall',
#  ',',
#  'wander',
#  'aboutamong',
#  'beds',
#  'bright',
#  'flowers',
#  'cool',
#  'fountains',
#  ',',
#  'butshe',
#  'could',
#  'even',
#  'get',
#  'head',
#  'doorway',
#  ';',
#  '`',
#  'even',
#  'ifmy',
#  'head',
#  'would',
#  'go',
#  ',',
#  "'",
#  'thought',
#  'poor',
#  'Alice',
#  ',',
#  '`',
#  'would',
#  'ofvery',
#  'little',
#  'use',
#  'without',
#  'shoulders',
#  '.',
#  'Oh',
#  ',',
#  'I',
#  'wishI',
#  'could',
#  'shut',
#  'like',
#  'telescope',
#  '!',
#  'I',
#  'think',
#  'I',
#  'could',
#  ',',
#  'I',
#  'onlyknow',
#  'begin',
#  '.',
#  "'",
#  'For',
#  ',',
#  'see',
#  ',',
#  'many',
#  'out-of-the-way',
#  'thingshad',
#  'happened',
#  'lately',
#  ',',
#  'Alice',
#  'begun',
#  'think',
#  'fewthings',
#  'indeed',
#  'really',
#  'impossible',
#  '.',
#  'There',
#  'seemed',
#  'use',
#  'waiting',
#  'little',
#  'door',
#  ',',
#  'shewent',
#  'back',
#  'table',
#  ',',
#  'half',
#  'hoping',
#  'might',
#  'find',
#  'another',
#  'key',
#  'onit',
#  ',',
#  'rate',
#  'book',
#  'rules',
#  'shutting',
#  'people',
#  'liketelescopes',
#  ':',
#  'time',
#  'found',
#  'little',
#  'bottle',
#  ',',
#  '(',
#  '`',
#  'whichcertainly',
#  ',',
#  "'",
#  'said',
#  'Alice',
#  ',',
#  ')',
#  'round',
#  'neckof',
#  'bottle',
#  'paper',
#  'label',
#  ',',
#  'words',
#  '`',
#  'DRINK',
#  "ME'beautifully",
#  'printed',
#  'large',
#  'letters',
#  '.',
#  'It',
#  'well',
#  'say',
#  ...]

# %%
# Create a new FreqDist for filtered_words

dist_words_filter = FreqDist(filtered_words)
print(dist_words_filter)
# Out:
# <FreqDist with 4010 samples and 21595 outcomes>

# %%
# Frequency Distribution Plot

plt.figure(figsize=(8, 3))
dist_words_filter.plot(10, cumulative = False)
plt.show()

# %%
dist_words_filter
# Out:
# FreqDist({',': 2418, '`': 1109, "'": 1076, '.': 920, 'I': 487, '!': 450, 'said': 434, 'Alice': 368, '--': 264, ':': 233, ...})

# %%
# Substitute all punctuations marks with a space 

sans_punc = re.sub("[^a-zA-Z]",  # Search for all non-letters
                          " ",          # Replace all non-letters with spaces
                          str(filtered_words))

# %%
sans_punc
# Out:
# '  Alice     s    Adventures    Wonderland    ALICE     S    ADVENTURES    IN    WONDERLAND    Lewis    Carroll    THE    MILLENNIUM    FULCRUM    EDITION           CHAPTER    I    Down    Rabbit Hole    Alice    beginning    get    tired    sitting    sisteron    bank         nothing         twice    hadpeeped    book    sister    reading         nopictures    conversations              use    book          thought    Alice         without    pictures    conversation              So    considering    mind         well    could         hot    day    made    feel    sleepy    stupid              whetherthe    pleasure    making    daisy chain    would    worth    troubleof    getting    picking    daisies         suddenly    WhiteRabbit    pink    eyes    ran    close         There    nothing    VERY    remarkable         Alicethink    VERY    much    way    hear    Rabbit    say    toitself              Oh    dear         Oh    dear         I    shall    late                   thoughtit    afterwards         occurred    ought    havewondered         time    seemed    quite    natural              Rabbit    actually    TOOK    A    WATCH    OUT    OF    ITS    WAISTCOAT POCKET         looked         hurried         Alice    started    toher    feet         flashed    across    mind    neverbefore    seen    rabbit    either    waistcoat pocket         watch    totake         burning    curiosity         ran    across    thefield         fortunately    time    see    popdown    large    rabbit hole    hedge         In    another    moment    went    Alice         never    onceconsidering    world    get         The    rabbit hole    went    straight    like    tunnel    way         dipped    suddenly         suddenly    Alice    amoment    think    stopping    found    herselffalling    deep    well         Either    well    deep         fell    slowly         shehad    plenty    time    went    look    towonder    going    happen    next         First         tried    lookdown    make    coming         dark    tosee    anything         looked    sides    well         andnoticed    filled    cupboards    book shelves         saw    maps    pictures    hung    upon    pegs         Shetook    jar    one    shelves    passed         waslabelled         ORANGE    MARMALADE              great    disappointment    itwas    empty         like    drop    jar    fear    killingsomebody         managed    put    one    cupboards    shefell    past              Well              thought    Alice              fall         Ishall    think    nothing    tumbling    stairs         How    brave    they llall    think    home         Why         I    would    n t    say    anything         even    I    fell    top    house                   Which    likelytrue              Down                   Would    fall    NEVER    come    end              Iwonder    many    miles    I     ve    fallen    time              said    aloud          I    must    getting    somewhere    near    centre    earth         Letme    see         would    four    thousand    miles         I    think                         see         Alice    learnt    several    things    sort    herlessons    schoolroom         though    VERY    goodopportunity    showing    knowledge         one    tolisten         still    good    practice    say                    yes          s    right    distance          I    wonder    Latitudeor    Longitude    I     ve    got                   Alice    idea    Latitude         Longitude    either         thought    nice    grand    words    tosay              Presently    began              I    wonder    I    shall    fall    rightTHROUGH    earth         How    funny     ll    seem    come    among    thepeople    walk    heads    downward         The    Antipathies         Ithink                    rather    glad    WAS    one    listening         thistime         n t    sound    right    word                    I    shallhave    ask     ...

# %%
# Word tokenization

tokenized_word_2 = word_tokenize(sans_punc)
print(tokenized_word_2)
# Out:
# ['Alice', 's', 'Adventures', 'Wonderland', 'ALICE', 'S', 'ADVENTURES', 'IN', 'WONDERLAND', 'Lewis', 'Carroll', 'THE', 'MILLENNIUM', 'FULCRUM', 'EDITION', 'CHAPTER', 'I', 'Down', 'Rabbit', 'Hole', 'Alice', 'beginning', 'get', 'tired', 'sitting', 'sisteron', 'bank', 'nothing', 'twice', 'hadpeeped', 'book', 'sister', 'reading', 'nopictures', 'conversations', 'use', 'book', 'thought', 'Alice', 'without', 'pictures', 'conversation', 'So', 'considering', 'mind', 'well', 'could', 'hot', 'day', 'made', 'feel', 'sleepy', 'stupid', 'whetherthe', 'pleasure', 'making', 'daisy', 'chain', 'would', 'worth', 'troubleof', 'getting', 'picking', 'daisies', 'suddenly', 'WhiteRabbit', 'pink', 'eyes', 'ran', 'close', 'There', 'nothing', 'VERY', 'remarkable', 'Alicethink', 'VERY', 'much', 'way', 'hear', 'Rabbit', 'say', 'toitself', 'Oh', 'dear', 'Oh', 'dear', 'I', 'shall', 'late', 'thoughtit', 'afterwards', 'occurred', 'ought', 'havewondered', 'time', 'seemed', 'quite', 'natural', 'Rabbit', 'actually', 'TOOK', 'A', 'WATCH', 'OUT', 'OF', 'ITS', 'WAISTCOAT', 'POCKET', 'looked', 'hurried', 'Alice', 'started', 'toher', 'feet', 'flashed', 'across', 'mind', 'neverbefore', 'seen', 'rabbit', 'either', 'waistcoat', 'pocket', 'watch', 'totake', 'burning', 'curiosity', 'ran', 'across', 'thefield', 'fortunately', 'time', 'see', 'popdown', 'large', 'rabbit', 'hole', 'hedge', 'In', 'another', 'moment', 'went', 'Alice', 'never', 'onceconsidering', 'world', 'get', 'The', 'rabbit', 'hole', 'went', 'straight', 'like', 'tunnel', 'way', 'dipped', 'suddenly', 'suddenly', 'Alice', 'amoment', 'think', 'stopping', 'found', 'herselffalling', 'deep', 'well', 'Either', 'well', 'deep', 'fell', 'slowly', 'shehad', 'plenty', 'time', 'went', 'look', 'towonder', 'going', 'happen', 'next', 'First', 'tried', 'lookdown', 'make', 'coming', 'dark', 'tosee', 'anything', 'looked', 'sides', 'well', 'andnoticed', 'filled', 'cupboards', 'book', 'shelves', 'saw', 'maps', 'pictures', 'hung', 'upon', 'pegs', 'Shetook', 'jar', 'one', 'shelves', 'passed', 'waslabelled', 'ORANGE', 'MARMALADE', 'great', 'disappointment', 'itwas', 'empty', 'like', 'drop', 'jar', 'fear', 'killingsomebody', 'managed', 'put', 'one', 'cupboards', 'shefell', 'past', 'Well', 'thought', 'Alice', 'fall', 'Ishall', 'think', 'nothing', 'tumbling', 'stairs', 'How', 'brave', 'they', 'llall', 'think', 'home', 'Why', 'I', 'would', 'n', 't', 'say', 'anything', 'even', 'I', 'fell', 'top', 'house', 'Which', 'likelytrue', 'Down', 'Would', 'fall', 'NEVER', 'come', 'end', 'Iwonder', 'many', 'miles', 'I', 've', 'fallen', 'time', 'said', 'aloud', 'I', 'must', 'getting', 'somewhere', 'near', 'centre', 'earth', 'Letme', 'see', 'would', 'four', 'thousand', 'miles', 'I', 'think', 'see', 'Alice', 'learnt', 'several', 'things', 'sort', 'herlessons', 'schoolroom', 'though', 'VERY', 'goodopportunity', 'showing', 'knowledge', 'one', 'tolisten', 'still', 'good', 'practice', 'say', 'yes', 's', 'right', 'distance', 'I', 'wonder', 'Latitudeor', 'Longitude', 'I', 've', 'got', 'Alice', 'idea', 'Latitude', 'Longitude', 'either', 'thought', 'nice', 'grand', 'words', 'tosay', 'Presently', 'began', 'I', 'wonder', 'I', 'shall', 'fall', 'rightTHROUGH', 'earth', 'How', 'funny', 'll', 'seem', 'come', 'among', 'thepeople', 'walk', 'heads', 'downward', 'The', 'Antipathies', 'Ithink', 'rather', 'glad', 'WAS', 'one', 'listening', 'thistime', 'n', 't', 'sound', 'right', 'word', 'I', 'shallhave', 'ask', 'name', 'country', 'know', 'Please', 'Ma', 'am', 'New', 'Zealand', 'Australia', 'triedto', 'curtsey', 'spoke', 'fancy', 'CURTSEYING', 're', 'fallingthrough', 'air', 'Do', 'think', 'could', 'manage', 'And', 'whatan', 'ignorant', 'little', 'girl', 'll', 'think', 'asking', 'No', 'it', 'llnever', 'ask', 'perhaps', 'I', 'shall', 'see', 'written', 'somewhere', 'Down', 'There', 'nothing', 'else', 'Alice', 'soonbegan', 'talking', 'Dinah', 'll', 'miss', 'much', 'to', 'night', 'Ishould', 'think', 'Dinah', 'cat', 'I', 'hope', 'll', 'rememberher', 'saucer', 'milk', 'tea', 'time ...

# %%
# Create a new FreqDist

dist_words_filter_2 = FreqDist(tokenized_word_2)

# %%
# Frequency Distribution Plot

plt.figure(figsize=(8, 3))
dist_words_filter_2.plot(30, cumulative = False)
plt.show()

# %%
dist_words_filter_2.most_common(20)
# Out:
# [('I', 507),
#  ('said', 441),
#  ('Alice', 369),
#  ('t', 209),
#  ('n', 207),
#  ('s', 187),
#  ('little', 107),
#  ('The', 106),
#  ('one', 82),
#  ('could', 79),
#  ('know', 77),
#  ('went', 75),
#  ('would', 71),
#  ('Queen', 69),
#  ('like', 68),
#  ('thought', 65),
#  ('And', 65),
#  ('It', 63),
#  ('time', 62),
#  ('see', 58)]

# %% [markdown]
# ## POS Tags with TextBlob

# %%
new_stopwords = ["And", "Then", 'n', 't', 's', 'The']

# %%
filtered = []
for word in tokenized_word_2:
    if word not in new_stopwords:
        filtered.append(word)

# %%
# %%time
text = TextBlob(str(filtered))
# Out:
# CPU times: total: 0 ns
# Wall time: 8.13 ms

# %%
text
# Out:
# TextBlob("['Alice', 'Adventures', 'Wonderland', 'ALICE', 'S', 'ADVENTURES', 'IN', 'WONDERLAND', 'Lewis', 'Carroll', 'THE', 'MILLENNIUM', 'FULCRUM', 'EDITION', 'CHAPTER', 'I', 'Down', 'Rabbit', 'Hole', 'Alice', 'beginning', 'get', 'tired', 'sitting', 'sisteron', 'bank', 'nothing', 'twice', 'hadpeeped', 'book', 'sister', 'reading', 'nopictures', 'conversations', 'use', 'book', 'thought', 'Alice', 'without', 'pictures', 'conversation', 'So', 'considering', 'mind', 'well', 'could', 'hot', 'day', 'made', 'feel', 'sleepy', 'stupid', 'whetherthe', 'pleasure', 'making', 'daisy', 'chain', 'would', 'worth', 'troubleof', 'getting', 'picking', 'daisies', 'suddenly', 'WhiteRabbit', 'pink', 'eyes', 'ran', 'close', 'There', 'nothing', 'VERY', 'remarkable', 'Alicethink', 'VERY', 'much', 'way', 'hear', 'Rabbit', 'say', 'toitself', 'Oh', 'dear', 'Oh', 'dear', 'I', 'shall', 'late', 'thoughtit', 'afterwards', 'occurred', 'ought', 'havewondered', 'time', 'seemed', 'quite', 'natural', 'Rabbit', 'actually', 'TOOK', 'A', 'WATCH', 'OUT', 'OF', 'ITS', 'WAISTCOAT', 'POCKET', 'looked', 'hurried', 'Alice', 'started', 'toher', 'feet', 'flashed', 'across', 'mind', 'neverbefore', 'seen', 'rabbit', 'either', 'waistcoat', 'pocket', 'watch', 'totake', 'burning', 'curiosity', 'ran', 'across', 'thefield', 'fortunately', 'time', 'see', 'popdown', 'large', 'rabbit', 'hole', 'hedge', 'In', 'another', 'moment', 'went', 'Alice', 'never', 'onceconsidering', 'world', 'get', 'rabbit', 'hole', 'went', 'straight', 'like', 'tunnel', 'way', 'dipped', 'suddenly', 'suddenly', 'Alice', 'amoment', 'think', 'stopping', 'found', 'herselffalling', 'deep', 'well', 'Either', 'well', 'deep', 'fell', 'slowly', 'shehad', 'plenty', 'time', 'went', 'look', 'towonder', 'going', 'happen', 'next', 'First', 'tried', 'lookdown', 'make', 'coming', 'dark', 'tosee', 'anything', 'looked', 'sides', 'well', 'andnoticed', 'filled', 'cupboards', 'book', 'shelves', 'saw', 'maps', 'pictures', 'hung', 'upon', 'pegs', 'Shetook', 'jar', 'one', 'shelves', 'passed', 'waslabelled', 'ORANGE', 'MARMALADE', 'great', 'disappointment', 'itwas', 'empty', 'like', 'drop', 'jar', 'fear', 'killingsomebody', 'managed', 'put', 'one', 'cupboards', 'shefell', 'past', 'Well', 'thought', 'Alice', 'fall', 'Ishall', 'think', 'nothing', 'tumbling', 'stairs', 'How', 'brave', 'they', 'llall', 'think', 'home', 'Why', 'I', 'would', 'say', 'anything', 'even', 'I', 'fell', 'top', 'house', 'Which', 'likelytrue', 'Down', 'Would', 'fall', 'NEVER', 'come', 'end', 'Iwonder', 'many', 'miles', 'I', 've', 'fallen', 'time', 'said', 'aloud', 'I', 'must', 'getting', 'somewhere', 'near', 'centre', 'earth', 'Letme', 'see', 'would', 'four', 'thousand', 'miles', 'I', 'think', 'see', 'Alice', 'learnt', 'several', 'things', 'sort', 'herlessons', 'schoolroom', 'though', 'VERY', 'goodopportunity', 'showing', 'knowledge', 'one', 'tolisten', 'still', 'good', 'practice', 'say', 'yes', 'right', 'distance', 'I', 'wonder', 'Latitudeor', 'Longitude', 'I', 've', 'got', 'Alice', 'idea', 'Latitude', 'Longitude', 'either', 'thought', 'nice', 'grand', 'words', 'tosay', 'Presently', 'began', 'I', 'wonder', 'I', 'shall', 'fall', 'rightTHROUGH', 'earth', 'How', 'funny', 'll', 'seem', 'come', 'among', 'thepeople', 'walk', 'heads', 'downward', 'Antipathies', 'Ithink', 'rather', 'glad', 'WAS', 'one', 'listening', 'thistime', 'sound', 'right', 'word', 'I', 'shallhave', 'ask', 'name', 'country', 'know', 'Please', 'Ma', 'am', 'New', 'Zealand', 'Australia', 'triedto', 'curtsey', 'spoke', 'fancy', 'CURTSEYING', 're', 'fallingthrough', 'air', 'Do', 'think', 'could', 'manage', 'whatan', 'ignorant', 'little', 'girl', 'll', 'think', 'asking', 'No', 'it', 'llnever', 'ask', 'perhaps', 'I', 'shall', 'see', 'written', 'somewhere', 'Down', 'There', 'nothing', 'else', 'Alice', 'soonbegan', 'talking', 'Dinah', 'll', 'miss', 'much', 'to', 'night', 'Ishould', 'think', 'Dinah', 'cat', 'I', 'hope', 'll', 'rememberher', 'saucer', 'milk', 'tea', 'time', 'Dinah', 'dear', 'I', 'wish', 'weredow ...

# %%
tags_list = text.tags

# %%
tags_list
# Out:
# [('[', 'JJ'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Adventures", 'NNS'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'ALICE", 'NNP'),
#  ("'", 'POS'),
#  ("'S", 'VBZ'),
#  ("'ADVENTURES", 'NNP'),
#  ("'", 'POS'),
#  ("'IN", 'NNP'),
#  ("'", 'POS'),
#  ("'WONDERLAND", 'CC'),
#  ("'Lewis", 'NNP'),
#  ("'", 'POS'),
#  ("'Carroll", 'NNP'),
#  ("'", 'POS'),
#  ("'MILLENNIUM", 'NNP'),
#  ("'", 'POS'),
#  ("'FULCRUM", 'NNP'),
#  ("'", 'POS'),
#  ("'EDITION", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'Rabbit", 'NNP'),
#  ("'", 'POS'),
#  ("'Hole", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'beginning", 'VBG'),
#  ("'get", 'NNP'),
#  ("'", 'POS'),
#  ("'tired", 'VBD'),
#  ("'sitting", 'VBG'),
#  ("'sisteron", 'NNP'),
#  ("'", 'POS'),
#  ("'bank", 'NNP'),
#  ("'", 'POS'),
#  ("'nothing", 'VBG'),
#  ("'twice", 'NNP'),
#  ("'", 'POS'),
#  ("'hadpeeped", 'VBD'),
#  ("'book", 'NNP'),
#  ("'", 'POS'),
#  ("'sister", 'NNP'),
#  ("'", 'POS'),
#  ("'reading", 'VBG'),
#  ("'nopictures", 'NNS'),
#  ("'", 'POS'),
#  ("'conversations", 'NNS'),
#  ("'", 'POS'),
#  ("'use", 'IN'),
#  ("'book", 'NNP'),
#  ("'", 'POS'),
#  ("'thought", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'without", 'IN'),
#  ("'pictures", 'NNS'),
#  ("'", 'POS'),
#  ("'conversation", 'NN'),
#  ("'So", 'NNP'),
#  ("'", 'POS'),
#  ("'considering", 'VBG'),
#  ("'mind", 'IN'),
#  ("'well", 'NNP'),
#  ("'", 'POS'),
#  ("'could", 'MD'),
#  ("'hot", 'NNP'),
#  ("'", 'POS'),
#  ("'feel", 'NNP'),
#  ("'", 'POS'),
#  ("'sleepy", 'NNP'),
#  ("'", 'POS'),
#  ("'stupid", 'NNP'),
#  ("'", 'POS'),
#  ("'whetherthe", 'NNP'),
#  ("'", 'POS'),
#  ("'pleasure", 'NN'),
#  ("'making", 'VBG'),
#  ("'daisy", 'NNP'),
#  ("'", 'POS'),
#  ("'would", 'MD'),
#  ("'troubleof", 'NNP'),
#  ("'", 'POS'),
#  ("'getting", 'VBG'),
#  ("'picking", 'VBG'),
#  ("'daisies", 'NNS'),
#  ("'", 'POS'),
#  ("'suddenly", 'RB'),
#  ("'WhiteRabbit", 'NNP'),
#  ("'", 'POS'),
#  ("'ran", 'NNP'),
#  ("'", 'POS'),
#  ("'close", 'NNP'),
#  ("'", 'POS'),
#  ("'There", 'EX'),
#  ("'nothing", 'VBG'),
#  ("'VERY", 'NNP'),
#  ("'", 'POS'),
#  ("'remarkable", 'JJ'),
#  ("'Alicethink", 'NNP'),
#  ("'", 'POS'),
#  ("'VERY", 'NNP'),
#  ("'", 'POS'),
#  ("'much", 'JJ'),
#  ("'way", 'NNP'),
#  ("'", 'POS'),
#  ("'Rabbit", 'NNP'),
#  ("'", 'POS'),
#  ("'say", 'NNP'),
#  ("'", 'POS'),
#  ("'toitself", 'PRP'),
#  ("'Oh", 'NNP'),
#  ("'", 'POS'),
#  ("'Oh", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'shall", 'DT'),
#  ("'late", 'NNP'),
#  ("'", 'POS'),
#  ("'thoughtit", 'NNP'),
#  ("'", 'POS'),
#  ("'afterwards", 'NNS'),
#  ("'", 'POS'),
#  ("'occurred", 'VBD'),
#  ("'ought", 'NNP'),
#  ("'", 'POS'),
#  ("'havewondered", 'VBD'),
#  ("'time", 'NNP'),
#  ("'", 'POS'),
#  ("'seemed", 'VBD'),
#  ("'quite", 'NNP'),
#  ("'", 'POS'),
#  ("'natural", 'NNP'),
#  ("'", 'POS'),
#  ("'actually", 'RB'),
#  ("'", 'POS'),
#  ("'TOOK", 'NNP'),
#  ("'", 'POS'),
#  ('A', 'NNP'),
#  ("'", 'POS'),
#  ("'WATCH", 'NNP'),
#  ("'", 'POS'),
#  ("'OUT", 'NNP'),
#  ("'", 'POS'),
#  ("'OF", 'NNP'),
#  ("'", 'POS'),
#  ("'WAISTCOAT", 'NNP'),
#  ("'", 'POS'),
#  ("'looked", 'VBD'),
#  ("'hurried", 'VBD'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'started", 'VBD'),
#  ("'toher", 'PRP'),
#  ("'feet", 'NNP'),
#  ("'", 'POS'),
#  ("'flashed", 'VBD'),
#  ("'across", 'IN'),
#  ("'mind", 'IN'),
#  ("'rabbit", 'NNP'),
#  ("'", 'POS'),
#  ("'either", 'PRP'),
#  ("'waistcoat", 'NNP'),
#  ("'", 'POS'),
#  ("'pocket", 'NNP'),
#  ("'", 'POS'),
#  ("'totake", 'NNP'),
#  ("'", 'POS'),
#  ("'burning", 'VBG'),
#  ("'curiosity", 'NNP'),
#  ("'", 'POS'),
#  ("'ran", 'NNP'),
#  ("'", 'POS'),
#  ("'across", 'IN'),
#  ("'thefield", 'NNP'),
#  ("'", 'POS'),
#  ("'fortunately", 'RB'),
#  ("'time", 'NNP'),
#  ("'", 'POS'),
#  ("'see", 'NNP'),
#  ("'", 'POS'),
#  ("'rabbit", 'NNP'),
#  ("'", 'POS'),
#  ("'hole", 'NNP'),
#  ("'", 'POS'),
#  ("'hedge", 'NNP'),
#  ("'", 'POS'),
#  ("'In", 'NNP'),
#  ("'", 'POS'),
#  ("'another", 'PRP'),
#  ("'moment", 'NNP'),
#  ("'", 'POS'),
#  ("'went", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'onceconsidering", 'VBG'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'get", 'NNP'),
#  ("'", 'POS'),
#  ("'hole", 'NNP'),
#  ("'", 'POS'),
#  ("'went", 'NNP'),
#  ("'", 'POS'),
#  ("'straight", 'NNP'),
#  ("'", 'POS'),
#  ("'like", 'IN'),
#  ("'tunnel", 'NNP'),
#  ("'", 'POS'),
#  ("'way", 'NNP'),
#  ("'", 'POS'),
#  ("'dipped", 'VBD'),
#  ("'suddenly", 'RB'),
#  ("'suddenly", 'RB'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'amoment", 'NNP'),
#  ("'", 'POS'),
#  ("'stopping", 'VBG'),
#  ("'found", 'IN'),
#  ("'herselffalling", 'VBG'),
#  ("'well", 'NNP'),
#  ("'", 'POS'),
#  ("'Either", 'PRP'),
#  ("'well", 'NNP'),
#  ("'", 'POS'),
#  ("'fell", 'NNP'),
#  ("'", 'POS'),
#  ("'slowly", 'NNP'),
#  ("'", 'POS'),
#  ("'shehad", 'VBD'),
#  ("'plenty", 'NNP'),
#  ("'", 'POS'),
#  ("'time", 'NNP'),
#  ("'", 'POS'),
#  ("'went", 'NNP'),
#  ("'", 'POS'),
#  ("'look", 'NNP'),
#  ("'", 'POS'),
#  ("'going", 'VBG'),
#  ("'happen", 'NNP'),
#  ("'", 'POS'),
#  ("'First", 'NNP'),
#  ("'", 'POS'),
#  ("'tried", 'VBD'),
#  ("'make", 'NNP'),
#  ("'", 'POS'),
#  ("'coming", 'VBG'),
#  ("'dark", 'NNP'),
#  ("'", 'POS'),
#  ("'tosee", 'NNP'),
#  ("'", 'POS'),
#  ("'anything", 'VBG'),
#  ("'looked", 'VBD'),
#  ("'sides", 'NNS'),
#  ("'", 'POS'),
#  ("'well", 'NNP'),
#  ("'", 'POS'),
#  ("'andnoticed", 'VBD'),
#  ("'filled", 'VBD'),
#  ("'cupboards", 'NNS'),
#  ("'", 'POS'),
#  ("'book", 'NNP'),
#  ("'", 'POS'),
#  ("'shelves", 'NNS'),
#  ("'", 'POS'),
#  ("'saw", 'NNP'),
#  ("'", 'POS'),
#  ("'maps", 'NNS'),
#  ("'", 'POS'),
#  ("'pictures", 'NNS'),
#  ("'", 'POS'),
#  ("'hung", 'NNP'),
#  ("'", 'POS'),
#  ("'pegs", 'NNP'),
#  ("'", 'POS'),
#  ("'Shetook", 'NNP'),
#  ("'", 'POS'),
#  ("'jar", 'NNP'),
#  ("'", 'POS'),
#  ("'one", 'CD'),
#  ("'shelves", 'NNS'),
#  ("'", 'POS'),
#  ("'passed", 'VBD'),
#  ("'waslabelled", 'VBD'),
#  ("'ORANGE", 'NNP'),
#  ("'", 'POS'),
#  ("'great", 'NNP'),
#  ("'", 'POS'),
#  ("'disappointment", 'NNP'),
#  ("'", 'POS'),
#  ("'itwas", 'NNP'),
#  ("'", 'POS'),
#  ("'empty", 'NNP'),
#  ("'", 'POS'),
#  ("'like", 'IN'),
#  ("'drop", 'NNP'),
#  ("'", 'POS'),
#  ("'jar", 'NNP'),
#  ("'", 'POS'),
#  ("'killingsomebody", 'NN'),
#  ("'managed", 'VBD'),
#  ("'put", 'NNP'),
#  ("'", 'POS'),
#  ("'one", 'CD'),
#  ("'cupboards", 'NNS'),
#  ("'", 'POS'),
#  ("'shefell", 'NNP'),
#  ("'", 'POS'),
#  ("'Well", 'NNP'),
#  ("'", 'POS'),
#  ("'thought", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Ishall", 'DT'),
#  ("'think", 'NNP'),
#  ("'", 'POS'),
#  ("'nothing", 'VBG'),
#  ("'tumbling", 'VBG'),
#  ("'stairs", 'PRP'),
#  ("'brave", 'NNP'),
#  ("'", 'POS'),
#  ("'they", 'NNP'),
#  ("'", 'POS'),
#  ("'think", 'NNP'),
#  ("'", 'POS'),
#  ("'home", 'NNP'),
#  ("'", 'POS'),
#  ("'Why", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'would", 'MD'),
#  ("'say", 'NNP'),
#  ("'", 'POS'),
#  ("'anything", 'VBG'),
#  ('I', 'PRP'),
#  ("'fell", 'NNP'),
#  ("'", 'POS'),
#  ("'top", 'NNP'),
#  ("'", 'POS'),
#  ("'house", 'IN'),
#  ("'Which", 'NNP'),
#  ("'", 'POS'),
#  ("'Would", 'MD'),
#  ("'fall", 'DT'),
#  ("'NEVER", 'NNP'),
#  ("'", 'POS'),
#  ("'come", 'NNP'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'miles", 'NNS'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'ve", 'VBP'),
#  ("'fallen", 'NNP'),
#  ("'", 'POS'),
#  ("'time", 'NNP'),
#  ("'", 'POS'),
#  ("'said", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'must", 'NNP'),
#  ("'", 'POS'),
#  ("'getting", 'VBG'),
#  ("'somewhere", 'EX'),
#  ("'near", 'IN'),
#  ("'centre", 'NNP'),
#  ("'", 'POS'),
#  ("'Letme", 'NNP'),
#  ("'", 'POS'),
#  ("'see", 'NNP'),
#  ("'", 'POS'),
#  ("'would", 'MD'),
#  ("'thousand", 'NNP'),
#  ("'", 'POS'),
#  ("'miles", 'NNS'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'think", 'NNP'),
#  ("'", 'POS'),
#  ("'see", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'learnt", 'NNP'),
#  ("'", 'POS'),
#  ("'several", 'NNP'),
#  ("'", 'POS'),
#  ("'things", 'NNS'),
#  ("'", 'POS'),
#  ("'sort", 'NNP'),
#  ("'", 'POS'),
#  ("'herlessons", 'NNS'),
#  ("'", 'POS'),
#  ("'schoolroom", 'NNP'),
#  ("'", 'POS'),
#  ("'though", 'IN'),
#  ("'VERY", 'NNP'),
#  ("'", 'POS'),
#  ("'goodopportunity", 'NNP'),
#  ("'", 'POS'),
#  ("'showing", 'VBG'),
#  ("'knowledge", 'NNP'),
#  ("'", 'POS'),
#  ("'one", 'CD'),
#  ("'still", 'NNP'),
#  ("'", 'POS'),
#  ("'good", 'NNP'),
#  ("'", 'POS'),
#  ("'practice", 'NNP'),
#  ("'", 'POS'),
#  ("'say", 'NNP'),
#  ("'", 'POS'),
#  ("'yes", 'NNS'),
#  ("'", 'POS'),
#  ("'right", 'NNP'),
#  ("'", 'POS'),
#  ("'distance", 'NN'),
#  ('I', 'PRP'),
#  ("'Latitudeor", 'NNP'),
#  ("'", 'POS'),
#  ("'Longitude", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'ve", 'VBP'),
#  ("'got", 'VBD'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'idea", 'NNP'),
#  ("'", 'POS'),
#  ("'Latitude", 'NNP'),
#  ("'", 'POS'),
#  ("'Longitude", 'NNP'),
#  ("'", 'POS'),
#  ("'either", 'PRP'),
#  ("'thought", 'NNP'),
#  ("'", 'POS'),
#  ("'nice", 'NNP'),
#  ("'", 'POS'),
#  ("'grand", 'NNP'),
#  ("'", 'POS'),
#  ("'words", 'NNS'),
#  ("'", 'POS'),
#  ("'tosay", 'NNP'),
#  ("'", 'POS'),
#  ("'Presently", 'RB'),
#  ("'began", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ('I', 'PRP'),
#  ("'shall", 'DT'),
#  ("'fall", 'DT'),
#  ("'rightTHROUGH", 'NNP'),
#  ("'", 'POS'),
#  ("'funny", 'NNP'),
#  ("'", 'POS'),
#  ("'ll", 'MD'),
#  ("'seem", 'NNP'),
#  ("'", 'POS'),
#  ("'come", 'NNP'),
#  ("'", 'POS'),
#  ("'among", 'NNP'),
#  ("'", 'POS'),
#  ("'heads", 'NNS'),
#  ("'", 'POS'),
#  ("'downward", 'NNP'),
#  ("'", 'POS'),
#  ("'Antipathies", 'NNS'),
#  ("'", 'POS'),
#  ("'rather", 'PRP'),
#  ("'glad", 'NNP'),
#  ("'", 'POS'),
#  ("'WAS", 'NNP'),
#  ("'", 'POS'),
#  ("'one", 'CD'),
#  ("'listening", 'VBG'),
#  ("'thistime", 'NNP'),
#  ("'", 'POS'),
#  ("'sound", 'IN'),
#  ("'right", 'NNP'),
#  ("'", 'POS'),
#  ("'word", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'shallhave", 'NNP'),
#  ("'", 'POS'),
#  ("'ask", 'NNP'),
#  ("'", 'POS'),
#  ("'country", 'NNP'),
#  ("'", 'POS'),
#  ("'know", 'NNP'),
#  ("'", 'POS'),
#  ("'Please", 'NNP'),
#  ("'", 'POS'),
#  ("'Ma", 'NNP'),
#  ("'", 'POS'),
#  ("'am", 'NNP'),
#  ("'", 'POS'),
#  ("'New", 'NNP'),
#  ("'", 'POS'),
#  ("'Zealand", 'NNP'),
#  ("'", 'POS'),
#  ("'Australia", 'NNP'),
#  ("'", 'POS'),
#  ("'triedto", 'NNP'),
#  ("'", 'POS'),
#  ("'curtsey", 'NNP'),
#  ("'", 'POS'),
#  ("'spoke", 'NNP'),
#  ("'", 'POS'),
#  ("'fancy", 'NN'),
#  ("'re", 'VBP'),
#  ("'fallingthrough", 'IN'),
#  ("'air", 'NNP'),
#  ("'", 'POS'),
#  ("'Do", 'NNP'),
#  ("'", 'POS'),
#  ("'could", 'MD'),
#  ("'manage", 'NN'),
#  ("'whatan", 'NNP'),
#  ("'", 'POS'),
#  ("'ignorant", 'NNP'),
#  ("'", 'POS'),
#  ("'little", 'NNP'),
#  ("'", 'POS'),
#  ("'girl", 'NNP'),
#  ("'", 'POS'),
#  ("'ll", 'MD'),
#  ("'think", 'NNP'),
#  ("'", 'POS'),
#  ("'asking", 'VBG'),
#  ("'No", 'NNP'),
#  ("'", 'POS'),
#  ("'it", 'NNP'),
#  ("'", 'POS'),
#  ("'ask", 'NNP'),
#  ("'", 'POS'),
#  ("'perhaps", 'NNS'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'shall", 'DT'),
#  ("'see", 'NNP'),
#  ("'", 'POS'),
#  ("'somewhere", 'EX'),
#  ("'There", 'EX'),
#  ("'nothing", 'VBG'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'soonbegan", 'NNP'),
#  ("'", 'POS'),
#  ("'talking", 'VBG'),
#  ("'Dinah", 'NNP'),
#  ("'", 'POS'),
#  ("'ll", 'MD'),
#  ("'much", 'JJ'),
#  ("'to", 'NNP'),
#  ("'", 'POS'),
#  ("'night", 'NNP'),
#  ("'", 'POS'),
#  ("'Ishould", 'MD'),
#  ("'think", 'NNP'),
#  ("'", 'POS'),
#  ("'Dinah", 'NNP'),
#  ("'", 'POS'),
#  ("'cat", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'ll", 'MD'),
#  ("'rememberher", 'PRP'),
#  ("'saucer", 'NNP'),
#  ("'", 'POS'),
#  ("'tea", 'NNP'),
#  ("'", 'POS'),
#  ("'time", 'NNP'),
#  ("'", 'POS'),
#  ("'Dinah", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'There", 'EX'),
#  ("'mice", 'NNP'),
#  ("'", 'POS'),
#  ("'air", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'m", 'VBP'),
#  ("'afraid", 'NNP'),
#  ("'", 'POS'),
#  ("'butyou", 'NNP'),
#  ("'", 'POS'),
#  ("'might", 'NNP'),
#  ("'", 'POS'),
#  ("'bat", 'NNP'),
#  ("'", 'POS'),
#  ("'like", 'IN'),
#  ("'mouse", 'IN'),
#  ("'know", 'NNP'),
#  ("'", 'POS'),
#  ("'But", 'NNP'),
#  ("'", 'POS'),
#  ("'cats", 'NNS'),
#  ("'", 'POS'),
#  ("'eat", 'NNP'),
#  ("'", 'POS'),
#  ("'bats", 'NNS'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'began", 'NNP'),
#  ("'", 'POS'),
#  ("'getrather", 'PRP'),
#  ("'sleepy", 'NNP'),
#  ("'", 'POS'),
#  ("'went", 'NNP'),
#  ("'", 'POS'),
#  ("'saying", 'VBG'),
#  ("'dreamy", 'NNP'),
#  ("'", 'POS'),
#  ("'sort", 'NNP'),
#  ("'", 'POS'),
#  ("'ofway", 'NNP'),
#  ("'", 'POS'),
#  ("'Do", 'NNP'),
#  ("'", 'POS'),
#  ("'cats", 'NNS'),
#  ("'", 'POS'),
#  ("'eat", 'NNP'),
#  ("'", 'POS'),
#  ("'bats", 'NNS'),
#  ("'", 'POS'),
#  ("'Do", 'NNP'),
#  ("'", 'POS'),
#  ("'cats", 'NNS'),
#  ("'", 'POS'),
#  ("'eat", 'NNP'),
#  ("'", 'POS'),
#  ("'bats", 'NNS'),
#  ("'", 'POS'),
#  ("'sometimes", 'NNS'),
#  ("'", 'POS'),
#  ("'Dobats", 'NNS'),
#  ("'", 'POS'),
#  ("'eat", 'NNP'),
#  ("'", 'POS'),
#  ("'cats", 'NNS'),
#  ("'", 'POS'),
#  ("'see", 'NNP'),
#  ("'", 'POS'),
#  ("'could", 'MD'),
#  ("'answer", 'JJR'),
#  ("'eitherquestion", 'NNP'),
#  ("'", 'POS'),
#  ("'much", 'JJ'),
#  ("'matter", 'NNP'),
#  ("'", 'POS'),
#  ("'way", 'NNP'),
#  ("'", 'POS'),
#  ("'put", 'NNP'),
#  ("'", 'POS'),
#  ("'She", 'NNP'),
#  ("'", 'POS'),
#  ("'feltthat", 'WP'),
#  ("'dozing", 'VBG'),
#  ("'begun", 'NNP'),
#  ("'", 'POS'),
#  ("'shewas", 'NNP'),
#  ("'", 'POS'),
#  ("'walking", 'VBG'),
#  ("'hand", 'NNP'),
#  ("'", 'POS'),
#  ("'hand", 'NNP'),
#  ("'", 'POS'),
#  ("'Dinah", 'NNP'),
#  ("'", 'POS'),
#  ("'saying", 'VBG'),
#  ("'veryearnestly", 'RB'),
#  ("'Now", 'NNP'),
#  ("'", 'POS'),
#  ("'Dinah", 'NNP'),
#  ("'", 'POS'),
#  ("'tell", 'NNP'),
#  ("'", 'POS'),
#  ("'truth", 'NNP'),
#  ("'", 'POS'),
#  ("'eat", 'NNP'),
#  ("'", 'POS'),
#  ("'abat", 'NNP'),
#  ("'", 'POS'),
#  ("'suddenly", 'RB'),
#  ("'thump", 'NNP'),
#  ("'", 'POS'),
#  ("'thump", 'NNP'),
#  ("'", 'POS'),
#  ("'heap", 'NNP'),
#  ("'", 'POS'),
#  ("'ofsticks", 'NNS'),
#  ("'", 'POS'),
#  ("'dry", 'NNP'),
#  ("'", 'POS'),
#  ("'leaves", 'NNS'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'hurt", 'NNP'),
#  ("'", 'POS'),
#  ("'jumped", 'VBD'),
#  ("'feet", 'NNP'),
#  ("'", 'POS'),
#  ("'amoment", 'NNP'),
#  ("'", 'POS'),
#  ("'looked", 'VBD'),
#  ("'dark", 'NNP'),
#  ("'", 'POS'),
#  ("'herwas", 'NNP'),
#  ("'", 'POS'),
#  ("'another", 'PRP'),
#  ("'long", 'NNP'),
#  ("'", 'POS'),
#  ("'passage", 'NN'),
#  ("'White", 'NNP'),
#  ("'", 'POS'),
#  ("'still", 'NNP'),
#  ("'", 'POS'),
#  ("'insight", 'NNP'),
#  ("'", 'POS'),
#  ("'hurrying", 'VBG'),
#  ("'There", 'EX'),
#  ("'moment", 'NNP'),
#  ("'", 'POS'),
#  ("'lost", 'FW'),
#  ("'", 'POS'),
#  ("'away", 'NNP'),
#  ("'", 'POS'),
#  ("'went", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'like", 'IN'),
#  ("'wind", 'IN'),
#  ("'time", 'NNP'),
#  ("'", 'POS'),
#  ("'itsay", 'NNP'),
#  ("'", 'POS'),
#  ("'turned", 'VBD'),
#  ("'corner", 'NNP'),
#  ("'", 'POS'),
#  ("'Oh", 'NNP'),
#  ("'", 'POS'),
#  ("'ears", 'NNS'),
#  ("'", 'POS'),
#  ("'whiskers", 'NNS'),
#  ("'", 'POS'),
#  ("'lateit", 'NNP'),
#  ("'", 'POS'),
#  ("'getting", 'VBG'),
#  ("'She", 'NNP'),
#  ("'", 'POS'),
#  ("'close", 'NNP'),
#  ("'", 'POS'),
#  ("'behind", 'IN'),
#  ("'turned", 'VBD'),
#  ("'thecorner", 'NNP'),
#  ("'", 'POS'),
#  ("'longer", 'NNP'),
#  ("'", 'POS'),
#  ("'foundherself", 'PRP'),
#  ("'long", 'NNP'),
#  ("'", 'POS'),
#  ("'low", 'NNP'),
#  ("'", 'POS'),
#  ("'lit", 'NNP'),
#  ("'", 'POS'),
#  ("'lampshanging", 'VBG'),
#  ("'roof", 'NNP'),
#  ("'", 'POS'),
#  ("'There", 'EX'),
#  ("'doors", 'NNS'),
#  ("'", 'POS'),
#  ("'round", 'IN'),
#  ("'hall", 'DT'),
#  ("'locked", 'VBD'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'way", 'NNP'),
#  ("'", 'POS'),
#  ("'one", 'CD'),
#  ("'side", 'NNP'),
#  ("'", 'POS'),
#  ("'theother", 'PRP'),
#  ("'trying", 'VBG'),
#  ("'every", 'NNP'),
#  ("'", 'POS'),
#  ("'door", 'NNP'),
#  ("'", 'POS'),
#  ("'walked", 'VBD'),
#  ("'sadly", 'RB'),
#  ("'middle", 'NNP'),
#  ("'", 'POS'),
#  ("'wondering", 'VBG'),
#  ("'get", 'NNP'),
#  ("'", 'POS'),
#  ("'Suddenly", 'RB'),
#  ("'little", 'NNP'),
#  ("'", 'POS'),
#  ("'legged", 'VBD'),
#  ("'table", 'JJ'),
#  ("'ofsolid", 'NNP'),
#  ("'", 'POS'),
#  ("'glass", 'NNP'),
#  ("'", 'POS'),
#  ("'nothing", 'VBG'),
#  ("'except", 'IN'),
#  ("'tiny", 'NNP'),
#  ("'", 'POS'),
#  ("'golden", 'NNP'),
#  ("'", 'POS'),
#  ("'key", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'first", 'NNP'),
#  ("'", 'POS'),
#  ("'thought", 'NNP'),
#  ("'", 'POS'),
#  ("'might", 'NNP'),
#  ("'", 'POS'),
#  ("'belong", 'NNP'),
#  ("'", 'POS'),
#  ("'one", 'CD'),
#  ("'thedoors", 'NNS'),
#  ("'", 'POS'),
#  ("'either", 'PRP'),
#  ("'locks", 'NNS'),
#  ("'", 'POS'),
#  ("'orthe", 'NNP'),
#  ("'", 'POS'),
#  ("'key", 'NNP'),
#  ("'", 'POS'),
#  ("'rate", 'NNP'),
#  ("'", 'POS'),
#  ("'would", 'MD'),
#  ("'open", 'NNP'),
#  ("'", 'POS'),
#  ("'ofthem", 'NNP'),
#  ("'", 'POS'),
#  ("'time", 'NNP'),
#  ("'", 'POS'),
#  ("'round", 'IN'),
#  ("'noticed", 'VBD'),
#  ("'behind", 'IN'),
#  ("'littledoor", 'NNP'),
#  ("'", 'POS'),
#  ("'inches", 'NNS'),
#  ("'", 'POS'),
#  ("'high", 'NNP'),
#  ("'", 'POS'),
#  ("'tried", 'VBD'),
#  ("'little", 'NNP'),
#  ("'", 'POS'),
#  ("'golden", 'NNP'),
#  ("'", 'POS'),
#  ("'keyin", 'NNP'),
#  ("'", 'POS'),
#  ("'lock", 'NNP'),
#  ("'", 'POS'),
#  ("'great", 'NNP'),
#  ("'", 'POS'),
#  ("'delight", 'NNP'),
#  ("'", 'POS'),
#  ("'fitted", 'VBD'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'opened", 'VBD'),
#  ("'door", 'NNP'),
#  ("'", 'POS'),
#  ("'found", 'IN'),
#  ("'led", 'VBD'),
#  ("'smallpassage", 'NN'),
#  ("'much", 'JJ'),
#  ("'larger", 'NNP'),
#  ("'", 'POS'),
#  ("'rat", 'NNP'),
#  ("'", 'POS'),
#  ("'hole", 'NNP'),
#  ("'", 'POS'),
#  ("'knelt", 'NNP'),
#  ("'", 'POS'),
#  ("'andlooked", 'VBD'),
#  ("'along", 'NNP'),
#  ("'", 'POS'),
#  ("'passage", 'NN'),
#  ("'loveliest", 'JJS'),
#  ("'garden", 'NNP'),
#  ("'", 'POS'),
#  ("'saw", 'NNP'),
#  ("'", 'POS'),
#  ("'longed", 'VBD'),
#  ("'get", 'NNP'),
#  ("'", 'POS'),
#  ("'dark", 'NNP'),
#  ("'", 'POS'),
#  ("'aboutamong", 'NNP'),
#  ("'", 'POS'),
#  ("'beds", 'NNS'),
#  ("'", 'POS'),
#  ("'bright", 'NNP'),
#  ("'", 'POS'),
#  ("'flowers", 'NNS'),
#  ("'", 'POS'),
#  ("'cool", 'NNP'),
#  ("'", 'POS'),
#  ("'fountains", 'NNS'),
#  ("'", 'POS'),
#  ("'butshe", 'NNP'),
#  ("'", 'POS'),
#  ("'could", 'MD'),
#  ("'get", 'NNP'),
#  ("'", 'POS'),
#  ("'doorway", 'NNP'),
#  ("'", 'POS'),
#  ("'ifmy", 'NNP'),
#  ("'", 'POS'),
#  ("'would", 'MD'),
#  ("'go", 'NNP'),
#  ("'", 'POS'),
#  ("'thought", 'NNP'),
#  ("'", 'POS'),
#  ("'poor", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'would", 'MD'),
#  ("'ofvery", 'NNP'),
#  ("'", 'POS'),
#  ("'little", 'NNP'),
#  ("'", 'POS'),
#  ("'use", 'IN'),
#  ("'without", 'IN'),
#  ("'shoulders", 'NNS'),
#  ("'", 'POS'),
#  ("'Oh", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'wishI", 'NNP'),
#  ("'", 'POS'),
#  ("'could", 'MD'),
#  ("'shut", 'NNP'),
#  ("'", 'POS'),
#  ("'like", 'IN'),
#  ('I', 'PRP'),
#  ("'think", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'could", 'MD'),
#  ('I', 'PRP'),
#  ("'onlyknow", 'NNP'),
#  ("'", 'POS'),
#  ("'For", 'NNP'),
#  ("'", 'POS'),
#  ("'see", 'NNP'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'out", 'IN'),
#  ("'of", 'NNP'),
#  ("'", 'POS'),
#  ("'the", 'NNP'),
#  ("'", 'POS'),
#  ("'way", 'NNP'),
#  ("'", 'POS'),
#  ("'thingshad", 'VBD'),
#  ("'happened", 'VBD'),
#  ("'lately", 'RB'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'begun", 'NNP'),
#  ("'", 'POS'),
#  ("'fewthings", 'NNS'),
#  ("'", 'POS'),
#  ("'really", 'RB'),
#  ("'", 'POS'),
#  ("'impossible", 'JJ'),
#  ("'There", 'EX'),
#  ("'seemed", 'VBD'),
#  ("'use", 'IN'),
#  ("'waiting", 'VBG'),
#  ("'little", 'NNP'),
#  ("'", 'POS'),
#  ("'door", 'NNP'),
#  ("'", 'POS'),
#  ("'shewent", 'NNP'),
#  ("'", 'POS'),
#  ("'table", 'JJ'),
#  ...]

# %%
df_text = pd.DataFrame(tags_list)
df_text.columns = ['Words', "Word type"]

# %%
df_text.head()
# Out:
#          Words Word type
# 0            [        JJ
# 1       'Alice       NNP
# 2            '       POS
# 3  'Adventures       NNS
# 4            '       POS

# %%
df_t = df_text.groupby('Word type').count().reset_index()

# %%
df_t.head()
# Out:
#   Word type  Words
# 0        CC      2
# 1        CD    199
# 2        DT     40
# 3        EX     65
# 4        FW     11

# %%
top20 = df_t.nlargest(20, 'Words')

# %%
plt.figure(figsize = (10, 5))
with sns.dark_palette("xkcd:blue", 20):
    sns.barplot(x = "Words", y = "Word type",
    saturation = 0.9, data = top20).set_title("Alice in Wonderland - top 20 word types used")

# %%
# def word_analysis(word_type):
#     filtered = [row for row in my_list if str(word_type) in row[1]]
#     print("filtered for " + word_type)
#     df = pd.DataFrame(filtered)
#     df.columns = ["Word", "Occurences"]
#     x=df.groupby('Word').count().reset_index()
#     y=x.sort_values(by=['Occurences'], ascending=False)
#     top10=y.nlargest(10, 'Occurences')
#     plt.figure(figsize=(10, 5))
#     sns.barplot(x="Word", y="Occurences", palette="rocket", saturation=0.9, data=top10).set_title("Lord of the rings - most frequently used "+ word_type +" type word")

# %% [markdown]
# #### Nouns

# %%
df = df_text[(df_text['Word type'] == "NN") | (df_text['Word type'] == "NNS") | (df_text['Word type'] == "NNP")]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurences'], ascending=False)
top10 = y.nlargest(10, 'Occurences')

# %%
top10
# Out:
#           Word  Occurences
# 1579     'said         441
# 11      'Alice         369
# 1225   'little         107
# 1173     'know          77
# 2072     'went          75
# 1913  'thought          65
# 156        'It          63
# 1929     'time          62
# 1610      'see          58
# 340    'Turtle          52

# %%
plt.figure(figsize=(10, 5))
with sns.dark_palette("xkcd:blue", 10):
    sns.barplot(x="Word", y="Occurences",
    saturation=0.9, data = top10).set_title("Alice in Wonderland - most frequently used nouns")

# %% [markdown]
# #### Verbs

# %%
df = df_text[(df_text['Word type'] == "VB")  | (df_text['Word type'] == "VBD")]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurences'], ascending=False)
top10 = y.nlargest(10, 'Occurences')

# %%
top10
# Out:
#          Word  Occurences
# 165   'looked          38
# 232  'replied          27
# 240   'seemed          22
# 17     'added          21
# 77     'cried          19
# 123      'got          18
# 302   'turned          16
# 299    'tried          15
# 55    'called          13
# 36     'asked          13

# %%
plt.figure(figsize = (10, 5))
with sns.dark_palette("xkcd:blue", 10):
    sns.barplot(x = "Word", y = "Occurences",
    saturation = 0.9, data = top10).set_title("Alice in Wonderland - most frequently used verbs")

# %% [markdown]
# #### Adjectives

# %%
df = df_text[df_text['Word type'] == "JJ"]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by=['Occurences'], ascending=False)
top10 = y.nlargest(10, 'Occurences')

# %%
plt.figure(figsize=(10, 5))
with sns.dark_palette("xkcd:blue", 10):
    sns.barplot(x="Word", y="Occurences",
    saturation=0.9, data=top10).set_title("Alice in Wonderland - most frequently used adjectives")

# %% [markdown]
# ## Counting character occurences

# %%
listToStr = ' '.join([str(elem) for elem in filtered])
 
print(listToStr)
# Out:
# Alice Adventures Wonderland ALICE S ADVENTURES IN WONDERLAND Lewis Carroll THE MILLENNIUM FULCRUM EDITION CHAPTER I Down Rabbit Hole Alice beginning get tired sitting sisteron bank nothing twice hadpeeped book sister reading nopictures conversations use book thought Alice without pictures conversation So considering mind well could hot day made feel sleepy stupid whetherthe pleasure making daisy chain would worth troubleof getting picking daisies suddenly WhiteRabbit pink eyes ran close There nothing VERY remarkable Alicethink VERY much way hear Rabbit say toitself Oh dear Oh dear I shall late thoughtit afterwards occurred ought havewondered time seemed quite natural Rabbit actually TOOK A WATCH OUT OF ITS WAISTCOAT POCKET looked hurried Alice started toher feet flashed across mind neverbefore seen rabbit either waistcoat pocket watch totake burning curiosity ran across thefield fortunately time see popdown large rabbit hole hedge In another moment went Alice never onceconsidering world get rabbit hole went straight like tunnel way dipped suddenly suddenly Alice amoment think stopping found herselffalling deep well Either well deep fell slowly shehad plenty time went look towonder going happen next First tried lookdown make coming dark tosee anything looked sides well andnoticed filled cupboards book shelves saw maps pictures hung upon pegs Shetook jar one shelves passed waslabelled ORANGE MARMALADE great disappointment itwas empty like drop jar fear killingsomebody managed put one cupboards shefell past Well thought Alice fall Ishall think nothing tumbling stairs How brave they llall think home Why I would say anything even I fell top house Which likelytrue Down Would fall NEVER come end Iwonder many miles I ve fallen time said aloud I must getting somewhere near centre earth Letme see would four thousand miles I think see Alice learnt several things sort herlessons schoolroom though VERY goodopportunity showing knowledge one tolisten still good practice say yes right distance I wonder Latitudeor Longitude I ve got Alice idea Latitude Longitude either thought nice grand words tosay Presently began I wonder I shall fall rightTHROUGH earth How funny ll seem come among thepeople walk heads downward Antipathies Ithink rather glad WAS one listening thistime sound right word I shallhave ask name country know Please Ma am New Zealand Australia triedto curtsey spoke fancy CURTSEYING re fallingthrough air Do think could manage whatan ignorant little girl ll think asking No it llnever ask perhaps I shall see written somewhere Down There nothing else Alice soonbegan talking Dinah ll miss much to night Ishould think Dinah cat I hope ll rememberher saucer milk tea time Dinah dear I wish weredown There mice air I m afraid butyou might catch bat like mouse know But cats eat bats I wonder Alice began getrather sleepy went saying dreamy sort ofway Do cats eat bats Do cats eat bats sometimes Dobats eat cats see could answer eitherquestion much matter way put She feltthat dozing begun dream shewas walking hand hand Dinah saying veryearnestly Now Dinah tell truth ever eat abat suddenly thump thump came upon heap ofsticks dry leaves fall Alice bit hurt jumped feet amoment looked dark overhead herwas another long passage White Rabbit still insight hurrying There moment lost away went Alice like wind time hear itsay turned corner Oh ears whiskers lateit getting She close behind turned thecorner Rabbit longer seen foundherself long low hall lit row lampshanging roof There doors round hall locked Alice way one side theother trying every door walked sadly middle wondering ever get Suddenly came upon little three legged table made ofsolid glass nothing except tiny golden key Alice first thought might belong one thedoors hall alas either locks large orthe key small rate would open ofthem However second time round came upon lowcurtain noticed behind littledoor fifteen inches high tried little golden keyin lock great delight fitted Alice opened door found ...

# %%
# Create a count for the main characters

all_counts = Counter(re.sub(r'\W+', ' ', listToStr).split())

# %%
all_counts
# Out:
# Counter({'Alice': 369,
#          'Adventures': 2,
#          'Wonderland': 1,
#          'ALICE': 3,
#          'S': 7,
#          'ADVENTURES': 1,
#          'IN': 2,
#          'WONDERLAND': 1,
#          'Lewis': 1,
#          'Carroll': 1,
#          'THE': 9,
#          'MILLENNIUM': 1,
#          'FULCRUM': 1,
#          'EDITION': 1,
#          'CHAPTER': 12,
#          'I': 507,
#          'Down': 3,
#          'Rabbit': 42,
#          'Hole': 1,
#          'beginning': 11,
#          'get': 40,
#          'tired': 7,
#          'sitting': 9,
#          'sisteron': 1,
#          'bank': 2,
#          'nothing': 30,
#          'twice': 5,
#          'hadpeeped': 1,
#          'book': 11,
#          'sister': 7,
#          'reading': 3,
#          'nopictures': 1,
#          'conversations': 1,
#          'use': 15,
#          'thought': 65,
#          'without': 23,
#          'pictures': 3,
#          'conversation': 7,
#          'So': 26,
#          'considering': 2,
#          'mind': 9,
#          'well': 40,
#          'could': 79,
#          'hot': 6,
#          'day': 25,
#          'made': 28,
#          'feel': 6,
#          'sleepy': 5,
#          'stupid': 5,
#          'whetherthe': 1,
#          'pleasure': 2,
#          'making': 5,
#          'daisy': 1,
#          'chain': 1,
#          'would': 71,
#          'worth': 3,
#          'troubleof': 1,
#          'getting': 18,
#          'picking': 2,
#          'daisies': 1,
#          'suddenly': 11,
#          'WhiteRabbit': 1,
#          'pink': 1,
#          'eyes': 25,
#          'ran': 14,
#          'close': 12,
#          'There': 32,
#          'VERY': 12,
#          'remarkable': 2,
#          'Alicethink': 1,
#          'much': 46,
#          'way': 48,
#          'hear': 11,
#          'say': 47,
#          'toitself': 1,
#          'Oh': 34,
#          'dear': 26,
#          'shall': 18,
#          'late': 5,
#          'thoughtit': 2,
#          'afterwards': 2,
#          'occurred': 2,
#          'ought': 11,
#          'havewondered': 1,
#          'time': 62,
#          'seemed': 22,
#          'quite': 46,
#          'natural': 4,
#          'actually': 1,
#          'TOOK': 1,
#          'A': 16,
#          'WATCH': 1,
#          'OUT': 1,
#          'OF': 3,
#          'ITS': 1,
#          'WAISTCOAT': 1,
#          'POCKET': 1,
#          'looked': 38,
#          'hurried': 9,
#          'started': 2,
#          'toher': 1,
#          'feet': 16,
#          'flashed': 1,
#          'across': 4,
#          'neverbefore': 1,
#          'seen': 12,
#          'rabbit': 4,
#          'either': 7,
#          'waistcoat': 1,
#          'pocket': 6,
#          'watch': 6,
#          'totake': 1,
#          'burning': 1,
#          'curiosity': 4,
#          'thefield': 1,
#          'fortunately': 1,
#          'see': 58,
#          'popdown': 1,
#          'large': 28,
#          'hole': 4,
#          'hedge': 1,
#          'In': 11,
#          'another': 18,
#          'moment': 24,
#          'went': 75,
#          'never': 35,
#          'onceconsidering': 1,
#          'world': 6,
#          'straight': 2,
#          'like': 68,
#          'tunnel': 1,
#          'dipped': 2,
#          'amoment': 3,
#          'think': 43,
#          'stopping': 1,
#          'found': 26,
#          'herselffalling': 1,
#          'deep': 6,
#          'Either': 1,
#          'fell': 5,
#          'slowly': 6,
#          'shehad': 3,
#          'plenty': 1,
#          'look': 22,
#          'towonder': 1,
#          'going': 21,
#          'happen': 7,
#          'next': 25,
#          'First': 6,
#          'tried': 15,
#          'lookdown': 1,
#          'make': 27,
#          'coming': 7,
#          'dark': 3,
#          'tosee': 3,
#          'anything': 18,
#          'sides': 4,
#          'andnoticed': 1,
#          'filled': 3,
#          'cupboards': 2,
#          'shelves': 2,
#          'saw': 12,
#          'maps': 1,
#          'hung': 1,
#          'upon': 22,
#          'pegs': 1,
#          'Shetook': 1,
#          'jar': 2,
#          'one': 82,
#          'passed': 5,
#          'waslabelled': 1,
#          'ORANGE': 1,
#          'MARMALADE': 1,
#          'great': 29,
#          'disappointment': 1,
#          'itwas': 4,
#          'empty': 1,
#          'drop': 1,
#          'fear': 4,
#          'killingsomebody': 1,
#          'managed': 3,
#          'put': 29,
#          'shefell': 1,
#          'past': 3,
#          'Well': 23,
#          'fall': 7,
#          'Ishall': 2,
#          'tumbling': 2,
#          'stairs': 2,
#          'How': 27,
#          'brave': 1,
#          'they': 2,
#          'llall': 1,
#          'home': 5,
#          'Why': 27,
#          'even': 15,
#          'top': 7,
#          'house': 16,
#          'Which': 7,
#          'likelytrue': 1,
#          'Would': 9,
#          'NEVER': 2,
#          'come': 22,
#          'end': 14,
#          'Iwonder': 2,
#          'many': 9,
#          'miles': 3,
#          've': 40,
#          'fallen': 4,
#          'said': 441,
#          'aloud': 5,
#          'must': 39,
#          'somewhere': 2,
#          'near': 13,
#          'centre': 1,
#          'earth': 4,
#          'Letme': 2,
#          'four': 7,
#          'thousand': 2,
#          'learnt': 2,
#          'several': 4,
#          'things': 25,
#          'sort': 18,
#          'herlessons': 1,
#          'schoolroom': 1,
#          'though': 10,
#          'goodopportunity': 1,
#          'showing': 2,
#          'knowledge': 2,
#          'tolisten': 1,
#          'still': 10,
#          'good': 22,
#          'practice': 1,
#          'yes': 1,
#          'right': 27,
#          'distance': 5,
#          'wonder': 13,
#          'Latitudeor': 1,
#          'Longitude': 2,
#          'got': 41,
#          'idea': 13,
#          'Latitude': 1,
#          'nice': 6,
#          'grand': 2,
#          'words': 19,
#          'tosay': 2,
#          'Presently': 2,
#          'began': 47,
#          'rightTHROUGH': 1,
#          'funny': 3,
#          'll': 51,
#          'seem': 6,
#          'among': 9,
#          'thepeople': 1,
#          'walk': 4,
#          'heads': 4,
#          'downward': 1,
#          'Antipathies': 1,
#          'Ithink': 2,
#          'rather': 18,
#          'glad': 9,
#          'WAS': 4,
#          'listening': 3,
#          'thistime': 2,
#          'sound': 4,
#          'word': 9,
#          'shallhave': 1,
#          'ask': 11,
#          'name': 10,
#          'country': 1,
#          'know': 77,
#          'Please': 5,
#          'Ma': 2,
#          'am': 1,
#          'New': 1,
#          'Zealand': 1,
#          'Australia': 1,
#          'triedto': 1,
#          'curtsey': 1,
#          'spoke': 16,
#          'fancy': 7,
#          'CURTSEYING': 1,
#          're': 36,
#          'fallingthrough': 1,
#          'air': 14,
#          'Do': 20,
#          'manage': 7,
#          'whatan': 1,
#          'ignorant': 1,
#          'little': 107,
#          'girl': 3,
#          'asking': 5,
#          'No': 20,
#          'it': 5,
#          'llnever': 1,
#          'perhaps': 13,
#          'written': 5,
#          'else': 11,
#          'soonbegan': 1,
#          'talking': 15,
#          'Dinah': 13,
#          'miss': 1,
#          'to': 4,
#          'night': 5,
#          'Ishould': 1,
#          'cat': 11,
#          'hope': 3,
#          'rememberher': 1,
#          'saucer': 1,
#          'milk': 2,
#          'tea': 17,
#          'wish': 18,
#          'weredown': 1,
#          'mice': 4,
#          'm': 48,
#          'afraid': 10,
#          'butyou': 1,
#          'might': 26,
#          'catch': 3,
#          'bat': 2,
#          'mouse': 12,
#          'But': 36,
#          'cats': 13,
#          'eat': 16,
#          'bats': 3,
#          'getrather': 1,
#          'saying': 13,
#          'dreamy': 1,
#          'ofway': 1,
#          'sometimes': 4,
#          'Dobats': 1,
#          'answer': 8,
#          'eitherquestion': 1,
#          'matter': 8,
#          'She': 38,
#          'feltthat': 1,
#          'dozing': 1,
#          'begun': 7,
#          'dream': 7,
#          'shewas': 2,
#          'walking': 4,
#          'hand': 18,
#          'veryearnestly': 2,
#          'Now': 12,
#          'tell': 26,
#          'truth': 1,
#          'ever': 14,
#          'abat': 1,
#          'thump': 2,
#          'came': 33,
#          'heap': 1,
#          'ofsticks': 1,
#          'dry': 8,
#          'leaves': 6,
#          'bit': 14,
#          'hurt': 3,
#          'jumped': 4,
#          'overhead': 1,
#          'herwas': 1,
#          'long': 27,
#          'passage': 3,
#          'White': 21,
#          'insight': 1,
#          'hurrying': 1,
#          'lost': 3,
#          'away': 21,
#          'wind': 2,
#          'itsay': 2,
#          'turned': 16,
#          'corner': 3,
#          'ears': 5,
#          'whiskers': 3,
#          'lateit': 1,
#          'behind': 9,
#          'thecorner': 1,
#          'longer': 3,
#          'foundherself': 1,
#          'low': 11,
#          'hall': 8,
#          'lit': 1,
#          'row': 2,
#          'lampshanging': 1,
#          'roof': 6,
#          'doors': 1,
#          'round': 36,
#          'locked': 1,
#          'side': 16,
#          'theother': 4,
#          'trying': 9,
#          'every': 9,
#          'door': 25,
#          'walked': 10,
#          'sadly': 5,
#          'middle': 7,
#          'wondering': 5,
#          'Suddenly': 1,
#          'three': 23,
#          'legged': 2,
#          'table': 17,
#          'ofsolid': 1,
#          'glass': 10,
#          'except': 4,
#          'tiny': 3,
#          'golden': 7,
#          'key': 8,
#          'first': 38,
#          'belong': 1,
#          'thedoors': 1,
#          'alas': 3,
#          'locks': 2,
#          'orthe': 1,
#          'small': 8,
#          'rate': 9,
#          'open': 6,
#          'ofthem': 2,
#          'However': 13,
#          'second': 4,
#          'lowcurtain': 1,
#          'noticed': 7,
#          'littledoor': 1,
#          'fifteen': 1,
#          'inches': 5,
#          'high': 14,
#          'keyin': 1,
#          'lock': 1,
#          'delight': 2,
#          'fitted': 1,
#          'opened': 10,
#          'led': 4,
#          'smallpassage': 1,
#          'larger': 7,
#          'rat': 1,
#          'knelt': 1,
#          'andlooked': 2,
#          'along': 6,
#          'loveliest': 1,
#          'garden': 16,
#          'longed': 2,
#          'wander': 1,
#          'aboutamong': 1,
#          'beds': 2,
#          'bright': 7,
#          'flowers': 2,
#          'cool': 2,
#          'fountains': 2,
#          'butshe': 3,
#          'head': 45,
#          'doorway': 1,
#          'ifmy': 1,
#          'go': 43,
#          'poor': 23,
#          'ofvery': 1,
#          'shoulders': 3,
#          'wishI': 1,
#          'shut': 4,
#          'telescope': 3,
#          'onlyknow': 1,
#          'begin': 10,
#          'For': 12,
#          'out': 4,
#          'of': 3,
#          'the': 5,
#          'thingshad': 1,
#          'happened': 7,
#          'lately': 1,
#          'fewthings': 1,
#          'indeed': 14,
#          'really': 10,
#          'impossible': 3,
#          'waiting': 8,
#          'shewent': 1,
#          'back': 32,
#          'half': 17,
#          'hoping': 2,
#          'find': 17,
#          'onit': 1,
#          'rules': 2,
#          'shutting': 2,
#          'people': 9,
#          'liketelescopes': 1,
#          'bottle': 9,
#          'whichcertainly': 1,
#          'neckof': 1,
#          'paper': 3,
#          'label': 2,
#          'DRINK': 2,
#          'ME': 7,
#          'beautifully': 2,
#          'printed': 1,
#          'letters': 1,
#          'It': 63,
#          'Drink': 1,
#          'wise': 2,
#          'littleAlice': 1,
#          'THAT': 13,
#          'hurry': 9,
#          'lookfirst': 1,
#          'whether': 8,
#          'marked': 6,
#          'poison': 3,
#          'read': 8,
#          'histories': 1,
#          'children': 10,
#          'whohad': 1,
#          'burnt': 1,
#          'eaten': 1,
#          'wild': 2,
#          'beasts': 2,
#          'unpleasantthings': 1,
#          'WOULD': 4,
#          'remember': 11,
#          'simple': 3,
#          'rulestheir': 1,
#          'friends': 2,
#          'taught': 3,
#          'red': 2,
#          'pokerwill': 1,
#          'burn': 2,
#          'hold': 6,
#          'cut': 4,
#          'yourfinger': 1,
#          'deeply': 4,
#          'knife': 3,
#          'usually': 2,
#          'bleeds': 1,
#          'hadnever': 2,
#          'forgotten': 6,
#          'drink': 3,
#          'almost': 5,
#          'certain': 2,
#          'disagree': 1,
#          'sooner': 2,
#          'orlater': 1,
#          'NOT': 7,
#          'venturedto': 1,
#          'taste': 1,
#          'finding': 3,
#          'fact': 7,
#          'sortof': 1,
#          'mixed': 2,
#          'flavour': 1,
#          'cherry': 1,
#          'tart': 1,
#          'custard': 1,
#          'pine': 1,
#          'apple': 1,
#          'roastturkey': 1,
#          'toffee': 1,
#          'buttered': 1,
#          'toast': 1,
#          'soon': 21,
#          'finishedit': 1,
#          'What': 41,
#          'curious': 13,
#          'feeling': 7,
#          'uplike': 1,
#          'ten': 4,
#          'andher': 2,
#          'face': 15,
#          'brightened': 2,
#          'rightsize': 1,
#          'lovely': 2,
#          'however': 7,
#          'waited': 10,
#          'minutes': 10,
#          'wasgoing': 1,
#          'shrink': 1,
#          'felt': 21,
#          'nervous': 4,
#          'aboutthis': 1,
#          'mygoing': 1,
#          'altogether': 5,
#          'candle': 3,
#          'belike': 1,
#          'flame': 1,
#          'islike': 1,
#          'blown': 1,
#          'rememberever': 2,
#          'thing': 40,
#          'After': 6,
#          'decidedon': 1,
#          'thelittle': 2,
#          'possibly': 3,
#          'reach': 4,
#          'itquite': 1,
#          'plainly': 1,
#          'best': 10,
#          'climbup': 1,
#          'legs': 3,
#          'slippery': 1,
#          'sat': 14,
#          'cried': 19,
#          'Come': 21,
#          'crying': 2,
#          'toherself': 5,
#          'sharply': 4,
#          'advise': 1,
#          'leave': 6,
#          'minute': 19,
#          'generally': 6,
#          'gave': 12,
#          'advice': 1,
#          'veryseldom': 1,
#          'followed': 8,
#          'scolded': 1,
#          'soseverely': 1,
#          'bring': 2,
#          'tears': 10,
#          'rememberedtrying': 1,
#          'box': 10,
#          'cheated': 1,
#          'gameof': 1,
#          'croquet': 7,
#          'playing': 2,
#          'curiouschild': 1,
#          'fond': 4,
#          'pretending': 1,
#          'two': 28,
#          'nouse': 3,
#          'pretend': 1,
#          'hardly': 10,
#          'enough': 17,
#          'left': 14,
#          'ONE': 4,
#          'respectableperson': 1,
#          'Soon': 1,
#          'eye': 7,
#          'lying': 8,
#          'underthe': 2,
#          'cake': 3,
#          'onwhich': 1,
#          'EAT': 1,
#          'currants': 1,
#          'makes': 10,
#          'grow': 13,
#          'smaller': 3,
#          'creepunder': 1,
#          'Ido': 4,
#          'care': 4,
#          'happens': 4,
#          'ate': 1,
#          'anxiously': 10,
#          'Whichway': 1,
#          'holding': 3,
#          'tofeel': 1,
#          'growing': 9,
#          'surprised': 5,
#          'tofind': 2,
#          'remained': 3,
#          'size': 11,
#          'sure': 17,
#          'generallyhappens': 1,
#          'eats': 1,
#          'theway': 2,
#          'expecting': 3,
#          'dull': 3,
#          'life': 12,
#          'thecommon': 1,
#          'set': 12,
#          'work': 7,
#          'finished': 10,
#          'II': 1,
#          'Pool': 1,
#          'Tears': 1,
#          'Curiouser': 1,
#          'curiouser': 1,
#          'muchsurprised': 1,
#          'forgot': 2,
#          'speak': 11,
#          'goodEnglish': 1,
#          'opening': 2,
#          'largest': 1,
#          'thatever': 1,
#          'Good': 1,
#          'bye': 2,
#          'herfeet': 1,
#          'sight': 9,
#          'sofar': 1,
#          'onyour': 1,
#          'shoes': 6,
#          'stockings': 1,
#          'dears': 2,
#          'shan': 1,
#          'tbe': 1,
#          'able': 1,
#          'deal': 12,
#          'far': 10,
#          'trouble': 5,
#          'myselfabout': 1,
#          'bekind': 1,
#          'wo': 24,
#          'want': 8,
#          'Let': 9,
#          'give': 8,
#          'new': 4,
#          'pair': 4,
#          'ofboots': 1,
#          'Christmas': 1,
#          'planning': 1,
#          'They': 20,
#          'carrier': 1,
#          'llseem': 1,
#          'sending': 2,
#          'presents': 2,
#          'odd': 1,
#          'thedirections': 1,
#          'RIGHT': 1,
#          'FOOT': 1,
#          'ESQ': 1,
#          'HEARTHRUG': 1,
#          'NEAR': 1,
#          'FENDER': 1,
#          'WITH': 1,
#          'LOVE': 1,
#          'nonsense': 6,
#          'Just': 7,
#          'struck': 2,
#          'infact': 1,
#          'nine': 4,
#          'tookup': 1,
#          'Poor': 2,
#          'oneside': 1,
#          'getthrough': 1,
#          'hopeless': 1,
#          'tocry': 1,
#          'You': 51,
#          'ashamed': 2,
#          'greatgirl': 1,
#          'inthis': 1,
#          'Stop': 1,
#          'allthe': 2,
#          'shedding': 1,
#          'gallons': 1,
#          'poolall': 1,
#          'reaching': 1,
#          'thehall': 1,
#          'heard': 29,
#          'pattering': 3,
#          'thedistance': 3,
#          'hastily': 15,
#          'dried': 1,
#          'returning': 1,
#          'splendidly': 1,
#          'dressed': 1,
#          'apair': 1,
#          'white': 7,
#          'kid': 4,
#          'gloves': 7,
#          'fan': 10,
#          'trotting': 2,
#          'muttering': 2,
#          'tohimself': 1,
#          'Duchess': 37,
#          'shebe': 1,
#          'savage': 3,
#          'kept': 11,
#          'desperatethat': 1,
#          'ready': 7,
#          'help': 9,
#          'Rabbitcame': 1,
#          'timid': 3,
#          'voice': 40,
#          'If': 16,
#          'please': 13,
#          'sir': 6,
#          'violently': 4,
#          'dropped': 4,
#          'kidgloves': 1,
#          'skurried': 1,
#          'darkness': 1,
#          'hardas': 1,
#          'took': 20,
#          'veryhot': 1,
#          'fanning': 1,
#          'Dear': 1,
#          'queer': 11,
#          'everything': 12,
#          'yesterdaythings': 1,
#          'usual': 5,
#          'changed': 7,
#          'inthe': 5,
#          'thismorning': 1,
#          'littledifferent': 1,
#          'question': 13,
#          'Who': 15,
#          'Ah': 5,
#          'puzzle': 1,
#          'beganthinking': 2,
#          'knew': 13,
#          'ageas': 1,
#          'Ada': 1,
#          'hair': 7,
#          'goes': 5,
#          'suchlong': 1,
#          'ringlets': 2,
#          'mine': 7,
#          'msure': 2,
#          'ca': 20,
#          'Mabel': 2,
#          'sorts': 2,
#          'oh': 10,
#          'knows': 2,
#          'Besides': 1,
#          'SHE': 5,
#          'puzzling': 4,
#          'try': 12,
#          'thethings': 1,
#          'used': 12,
#          'times': 6,
#          'five': 1,
#          'twelve': 3,
#          'six': 2,
#          'thirteen': 1,
#          'seven': 1,
#          'twenty': 2,
#          'theMultiplication': 1,
#          'Table': 1,
#          'signify': 1,
#          'let': 10,
#          'Geography': 1,
#          'London': 1,
#          'capital': 3,
#          'Paris': 2,
#          'Rome': 2,
#          'wrong': 5,
#          'beenchanged': 1,
#          'doth': 2,
#          'and': 8,
#          'crossed': 3,
#          'hands': 11,
#          'lap': 2,
#          'lessons': 8,
#          'repeat': 4,
#          'sounded': 4,
#          'hoarse': 2,
#          'andstrange': 1,
#          'crocodile': 1,
#          'Improve': 1,
#          'shining': 1,
#          'tail': 9,
#          'pour': 1,
#          'waters': 1,
#          'Nile': 1,
#          'On': 4,
#          'scale': 1,
#          'cheerfully': 1,
#          'seems': 4,
#          'grin': 6,
#          'neatly': 2,
#          'spread': 2,
#          'claws': 2,
#          'welcome': 1,
#          'fishes': 1,
#          'With': 3,
#          'gently': 1,
#          'smiling': 2,
#          'jaws': 2,
#          'Mabelafter': 1,
#          'live': 7,
#          'poky': 1,
#          'littlehouse': 1,
#          'toys': 1,
#          'play': 8,
#          'somany': 2,
#          'learn': 6,
#          'mMabel': 1,
#          'stay': 5,
#          'putting': 3,
#          'theirheads': 2,
#          'lookup': 1,
#          'Tell': 5,
#          'Ilike': 2,
#          'person': 3,
#          'downhere': 1,
#          'till': 18,
#          'somebody': 4,
#          'asudden': 1,
#          'burst': 1,
#          'headsdown': 1,
#          'alone': 4,
#          'As': 17,
#          'wassurprised': 1,
#          'littlewhite': 1,
#          'CAN': 4,
#          'donethat': 1,
#          'upand': 3,
#          'measure': 1,
#          'nearly': 7,
#          'guess': 3,
#          'shrinking': 3,
#          'rapidly': 1,
#          'thecause': 1,
#          'ithastily': 1,
#          'avoid': 1,
#          'That': 27,
#          'narrow': 1,
#          'escape': 4,
#          'frightened': 5,
#          'atthe': 2,
#          'sudden': 4,
#          'change': 13,
#          'inexistence': 1,
#          'speedback': 1,
#          'shutagain': 1,
#          'asbefore': 1,
#          'worse': 3,
#          'child': 10,
#          'declareit': 1,
#          'bad': 1,
#          'foot': 7,
#          'slipped': 3,
#          'anothermoment': 1,
#          'splash': 1,
#          'chin': 7,
#          'salt': 1,
#          'water': 3,
#          'Her': 3,
#          'firstidea': 1,
#          'somehow': 1,
#          'sea': 14,
#          'thatcase': 1,
#          'railway': 2,
#          'hadbeen': 1,
#          'seaside': 1,
#          'generalconclusion': 1,
#          'wherever': 2,
#          'English': 5,
#          'coast': 1,
#          'finda': 1,
#          'number': 4,
#          'bathing': 1,
#          'machines': 1,
#          'digging': 2,
#          'sand': 1,
#          'wooden': 1,
#          'spades': 1,
#          'lodging': 1,
#          'houses': 1,
#          'andbehind': 1,
#          'station': 1,
#          'thatshe': 2,
#          'pool': 9,
#          'wept': 1,
#          'ninefeet': 1,
#          'swam': 4,
#          'punished': 1,
#          'Isuppose': 2,
#          'drowned': 1,
#          'WILL': 3,
#          'queerthing': 1,
#          'something': 14,
#          'splashing': 1,
#          'alittle': 5,
#          'nearer': 5,
#          'atfirst': 2,
#          'walrus': 1,
#          'hippopotamus': 1,
#          'thenshe': 2,
#          'remembered': 3,
#          'thatit': 2,
#          'thismouse': 1,
#          'Everything': 2,
#          'shouldthink': 1,
#          'likely': 4,
#          'talk': 14,
#          'harm': 1,
#          'intrying': 1,
#          'O': 3,
#          'Mouse': 29,
#          'ofthis': 2,
#          'swimming': 2,
#          'speaking': 5,
#          'done': 13,
#          'havingseen': 1,
#          'brother': 1,
#          'Latin': 1,
#          'Grammar': 1,
#          'amouse': 1,
#          'ratherinquisitively': 1,
#          'wink': 2,
#          'littleeyes': 1,
#          'Perhaps': 3,
#          'understand': 5,
#          'Idaresay': 1,
#          'French': 4,
#          'William': 5,
#          'theConqueror': 1,
#          'history': 6,
#          'hadno': 1,
#          'clear': 2,
#          'notion': 3,
#          'ago': 2,
#          'shebegan': 1,
#          'Ou': 1,
#          'est': 1,
#          'chatte': 1,
#          'sentence': 5,
#          'inher': 2,
#          'lesson': 3,
#          'leap': 1,
#          ...})

# %%
chars = pd.read_csv("Alice_characters.csv", index_col = 0)

# %%
chars.head()
# Out:
#           character
# 0             Alice
# 1  The White Rabbit
# 2         The Mouse
# 3          The Dodo
# 4          The Lory

# %%
# Replace names with aliases

chars['character'] = chars['character'].replace('Bill the Lizard','Bill')
chars['character'] = chars['character'].replace('The Queen of Hearts','Queen')
chars['character'] = chars['character'].replace('The King of Hearts','King')
chars['character'] = chars['character'].replace('The Knave of Hearts','Knave')

# %%
chars
# Out:
#            character
# 0              Alice
# 1   The White Rabbit
# 2          The Mouse
# 3           The Dodo
# 4           The Lory
# 5         The Eaglet
# 6           The Duck
# 7                Pat
# 8               Bill
# 9              Puppy
# 10   The Caterpillar
# 11       The Duchess
# 12  The Cheshire Cat
# 13        The Hatter
# 14    The March Hare
# 15      The Dormouse
# 16             Queen
# 17              King
# 18             Knave
# 19       The Gryphon
# 20   The Mock Turtle

# %%
chars['character_alias'] = chars['character'].apply(lambda x: x.rsplit(' ', 1)[-1])

# %%
chars
# Out:
#            character character_alias
# 0              Alice           Alice
# 1   The White Rabbit          Rabbit
# 2          The Mouse           Mouse
# 3           The Dodo            Dodo
# 4           The Lory            Lory
# 5         The Eaglet          Eaglet
# 6           The Duck            Duck
# 7                Pat             Pat
# 8               Bill            Bill
# 9              Puppy           Puppy
# 10   The Caterpillar     Caterpillar
# 11       The Duchess         Duchess
# 12  The Cheshire Cat             Cat
# 13        The Hatter          Hatter
# 14    The March Hare            Hare
# 15      The Dormouse        Dormouse
# 16             Queen           Queen
# 17              King            King
# 18             Knave           Knave
# 19       The Gryphon         Gryphon
# 20   The Mock Turtle          Turtle

# %%
char_list = chars['character_alias'].to_list()

# %%
dict_of_counts = {d : all_counts[d] for d in char_list}

# %%
dict_of_counts
# Out:
# {'Alice': 369,
#  'Rabbit': 42,
#  'Mouse': 29,
#  'Dodo': 12,
#  'Lory': 7,
#  'Eaglet': 3,
#  'Duck': 2,
#  'Pat': 3,
#  'Bill': 14,
#  'Puppy': 0,
#  'Caterpillar': 25,
#  'Duchess': 37,
#  'Cat': 25,
#  'Hatter': 51,
#  'Hare': 30,
#  'Dormouse': 32,
#  'Queen': 69,
#  'King': 57,
#  'Knave': 9,
#  'Gryphon': 49,
#  'Turtle': 52}

# %%
# Search for the names from the list in the dictionary

dct = {v:[k] for v,k in dict_of_counts.items()}  
df = pd.DataFrame(dct)

# %%
df
# Out:
#    Alice  Rabbit  Mouse  Dodo  Lory  Eaglet  Duck  Pat  Bill  Puppy  ...  \
# 0    369      42     29    12     7       3     2    3    14      0  ...
#
#    Duchess  Cat  Hatter  Hare  Dormouse  Queen  King  Knave  Gryphon  Turtle
# 0       37   25      51    30        32     69    57      9       49      52
#
# [1 rows x 21 columns]

# %%
df = df.transpose().reset_index()

# %%
df.dtypes
# Out:
# index    object
# 0         int64
# dtype: object

# %%
df
# Out:
#           index    0
# 0         Alice  369
# 1        Rabbit   42
# 2         Mouse   29
# 3          Dodo   12
# 4          Lory    7
# 5        Eaglet    3
# 6          Duck    2
# 7           Pat    3
# 8          Bill   14
# 9         Puppy    0
# 10  Caterpillar   25
# 11      Duchess   37
# 12          Cat   25
# 13       Hatter   51
# 14         Hare   30
# 15     Dormouse   32
# 16        Queen   69
# 17         King   57
# 18        Knave    9
# 19      Gryphon   49
# 20       Turtle   52

# %%
df.rename(columns = {"index":"Character", 0:"Times mentioned"}, inplace = True)

# %%
df
# Out:
#       Character  Times mentioned
# 0         Alice              369
# 1        Rabbit               42
# 2         Mouse               29
# 3          Dodo               12
# 4          Lory                7
# 5        Eaglet                3
# 6          Duck                2
# 7           Pat                3
# 8          Bill               14
# 9         Puppy                0
# 10  Caterpillar               25
# 11      Duchess               37
# 12          Cat               25
# 13       Hatter               51
# 14         Hare               30
# 15     Dormouse               32
# 16        Queen               69
# 17         King               57
# 18        Knave                9
# 19      Gryphon               49
# 20       Turtle               52

# %%
df.shape
# Out:
# (21, 2)

# %%
plt.figure(figsize=(10, 5))
with sns.dark_palette("#79C", 27):
    sns.barplot(x = "Times mentioned", y = "Character",
    saturation=0.9, data = df.sort_values("Times mentioned", ascending = False)).set_title("Alice in Wonderland - most frequently mentioned characters")

# %%
chars.to_csv("characters_alice.csv")

# %% [markdown]
# ## Sentiment Analysis

# %%
text_sent = TextBlob(str(filtered))

# %%
print(text_sent.sentiment)
# Out:
# Sentiment(polarity=0.04454487996502118, subjectivity=0.4972800403573339)
